# %% [markdown]
# # Workplace Safety PPE Detection System - Model Evaluation
# ## DeMarcus Crump & Chloe Tu | ITAI 1378 | Final Project
#
# This notebook evaluates our trained YOLOv8 model on the test set. We calculate comprehensive performance metrics, generate confusion matrices, analyze per-class accuracy, and identify challenging cases where the model struggles. This analysis helps us understand the model's real-world applicability and limitations.

# %% [markdown]
# ## Mount Google Drive
#
# Mounting Google Drive to access the trained model and test dataset from previous notebooks.

# %%
from google.colab import drive
drive.mount('/content/drive')

print("=" * 60)
print("✓ Google Drive mounted successfully!")
print("=" * 60)
# Out:
# Mounted at /content/drive
# ============================================================
# ✓ Google Drive mounted successfully!
# ============================================================

# %% [markdown]
# ## Model Loading
#
# Loading the best checkpoint from training (based on validation mAP). This model hasn't seen the test set yet, so these results represent true generalization performance.

# %%
from ultralytics import YOLO
import torch
import numpy as np
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from collections import defaultdict
import pandas as pd
import os
import glob
import warnings
warnings.filterwarnings('ignore')

# Load best trained model from latest training run
run_folders = glob.glob('/content/drive/MyDrive/PPE_Project/runs/detect/ppe_detection*')
if run_folders:
    latest_run = max(run_folders, key=os.path.getmtime)
    model_path = f'{latest_run}/weights/best.pt'
    print(f"Loading model from: {latest_run}")
else:
    # Fallback to default
    model_path = '/content/drive/MyDrive/PPE_Project/runs/detect/ppe_detection/weights/best.pt'
    print(f"Loading model from: {model_path}")

model = YOLO(model_path)
print("=" * 60)
print("✓ Best trained model loaded successfully!")
print("=" * 60)
# Out:
# Loading model from: /content/drive/MyDrive/PPE_Project/runs/detect/ppe_detection4
# ============================================================
# ✓ Best trained model loaded successfully!
# ============================================================

# %% [markdown]
# ## PPE Classes and Colors
#
# Class definitions and color mappings for consistent visualization throughout evaluation.

# %%
# PPE class definitions
ppe_classes = {
    0: 'Hardhat',
    1: 'NO-Hardhat',
    2: 'Safety Vest',
    3: 'NO-Safety Vest',
    4: 'Mask',
    5: 'NO-Mask',
    6: 'Person',
    7: 'Safety Cone',
    8: 'Machinery',
    9: 'Vehicle'
}

# Color mapping for each class (RGB format for OpenCV)
class_colors = {
    0: (255, 0, 0),      # Hardhat - Red
    1: (0, 0, 255),      # NO-Hardhat - Blue
    2: (0, 255, 0),      # Safety Vest - Green
    3: (255, 255, 0),    # NO-Safety Vest - Cyan
    4: (255, 0, 255),    # Mask - Magenta
    5: (128, 0, 128),    # NO-Mask - Purple
    6: (255, 128, 0),    # Person - Orange
    7: (0, 255, 255),    # Safety Cone - Lime
    8: (128, 128, 0),    # Machinery - Olive
    9: (0, 128, 128)     # Vehicle - Teal
}

print("PPE Classes Configured:")
print("=" * 60)
for class_id, class_name in ppe_classes.items():
    print(f"  {class_id}: {class_name}")
print("=" * 60)
# Out:
# PPE Classes Configured:
# ============================================================
#   0: Hardhat
#   1: NO-Hardhat
#   2: Safety Vest
#   3: NO-Safety Vest
#   4: Mask
#   5: NO-Mask
#   6: Person
#   7: Safety Cone
#   8: Machinery
#   9: Vehicle
# ============================================================

# %% [markdown]
# ## Test Set Validation
#
# Running official YOLO validation against the test set to get standard object detection metrics.
#
# **Key Metrics:**
# - **mAP@50**: Mean Average Precision at 50% IoU (industry standard for object detection)
# - **mAP@50-95**: Stricter metric averaged across IoU thresholds 0.50 to 0.95
# - **Precision**: Percentage of correct predictions among all detections
# - **Recall**: Percentage of actual objects successfully detected

# %%
# Run official validation on test set
print("Running validation on test set...")
print("=" * 60)

val_results = model.val(data='/content/drive/MyDrive/PPE_Project/dataset.yaml', split='test', device=0)

print("\nValidation Results:")
print("=" * 60)
print(f"mAP@50:       {val_results.box.map50:.4f}")
print(f"mAP@50-95:    {val_results.box.map:.4f}")
print(f"Precision:    {val_results.box.mp:.4f}")
print(f"Recall:       {val_results.box.mr:.4f}")
print("=" * 60)
# Out:
# Running validation on test set...
# ============================================================
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# Model summary (fused): 72 layers, 11,129,454 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 36.8±21.2 MB/s, size: 63.1 KB)
# val: Scanning /content/drive/MyDrive/PPE_Project/dataset_resplit/labels/test.cache... 423 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 423/423 634.8Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 4.5it/s 6.0s
#                    all        423       5645      0.889      0.689      0.771      0.501
#                Hardhat        190        481      0.915      0.739      0.809      0.528
#             NO-Hardhat        114        152      0.938      0.891      0.945      0.645
#            Safety Vest        189        303      0.865      0.627       0.68       0.39
#         NO-Safety Vest        224        494      0.833      0.553      0.649      0.324
#                   Mask        263        521      0.866      0.666      0.755      0.482
#                NO-Mask        390       1342      0.898      0.744       0.84      0.582
#                 Person         94        581      0.888      0.449      0.577      0.278
#            Safety Cone        213        489        0.9      0.746      0.822      0.535
#              Machinery        377        987      0.929      0.861      0.931      0.749
#                Vehicle        145        295      0.863       0.61      0.702      0.493
# Speed: 1.1ms preprocess, 4.1ms inference, 0.0ms loss, 3.9ms postprocess per image
# Results saved to /content/runs/detect/val2
#
# Validation Results:
# ============================================================
# mAP@50:       0.7710
# mAP@50-95:    0.5006
# Precision:    0.8894
# Recall:       0.6887
# ============================================================

# %% [markdown]
# ## Inference with Confidence Scores
#
# Running inference on all test images to collect predictions and confidence scores. This lets us analyze detection patterns across different PPE classes.
#
# **Parameters:**
# - **conf**: 0.25 minimum confidence threshold
# - **iou**: 0.45 threshold for Non-Maximum Suppression (removes duplicate overlapping detections)

# %%
# Run inference on all test images
test_dir = Path('/content/drive/MyDrive/PPE_Project/dataset_resplit/images/test')
test_images = sorted(list(test_dir.glob('*.jpg')))

print(f"Running inference on {len(test_images)} test images...")
print("=" * 60)

predictions = []

for img_path in test_images:
    results = model(str(img_path), conf=0.25, iou=0.45)

    for result in results:
        for box in result.boxes:
            predictions.append({
                'image': img_path.name,
                'class_id': int(box.cls),
                'class_name': ppe_classes[int(box.cls)],
                'confidence': float(box.conf),
                'x1': float(box.xyxy[0][0]),
                'y1': float(box.xyxy[0][1]),
                'x2': float(box.xyxy[0][2]),
                'y2': float(box.xyxy[0][3])
            })

pred_df = pd.DataFrame(predictions)

print(f"✓ Inference complete!")
print(f"Total Detections: {len(predictions)}")
print("\nDetection Statistics by Class:")
print("=" * 60)
print(pred_df['class_name'].value_counts().to_string())
print("=" * 60)
# Out:
# Running inference on 423 test images...
# ============================================================
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/003184_jpg.rf.e7b83a5faa2513c5d2201944e2b2bd17.jpg: 640x640 2 Masks, 5 NO-Masks, 3 Machinerys, 1 Vehicle, 7.4ms
# Speed: 2.0ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/005310_jpg.rf.3fadf8fa69fb354db06bed4e42142276.jpg: 640x640 3 Hardhats, 1 NO-Safety Vest, 2 Masks, 4 NO-Masks, 1 Safety Cone, 1 Machinery, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/005310_jpg.rf.462b38e32ee1aed612c4ed119dc9a06e.jpg: 640x640 1 Hardhat, 3 NO-Masks, 6 Persons, 2 Safety Cones, 1 Machinery, 1 Vehicle, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/005310_jpg.rf.5b524ed76d3e591d22c323212f22943f.jpg: 640x640 7 Machinerys, 1 Vehicle, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/006858_jpg.rf.c94da6aa210f1738a87f3525da7b5985.jpg: 640x640 1 NO-Hardhat, 2 Safety Vests, 1 NO-Safety Vest, 6 Masks, 5 NO-Masks, 1 Machinery, 1 Vehicle, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/129_jpg.rf.3ddb7831c49cc812f103617cf0da07fa.jpg: 640x640 1 NO-Hardhat, 1 Mask, 2 NO-Masks, 2 Persons, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/129_jpg.rf.6ffe5c397bf302ae2bf05108d292a3f8.jpg: 640x640 2 Hardhats, 1 NO-Hardhat, 1 Safety Vest, 1 NO-Safety Vest, 3 Masks, 3 NO-Masks, 2 Persons, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/1582_jpg.rf.a067bc50920883d43cd5cab0a1966ad4.jpg: 640x640 1 Safety Vest, 2 NO-Masks, 2 Vehicles, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/165_jpg.rf.8e28e2ec55d7ab727f8a5cd072024dd2.jpg: 640x640 1 NO-Hardhat, 2 Masks, 2 NO-Masks, 2 Persons, 2 Machinerys, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/2008_008629_jpg.rf.85c2d54a785a02b9c6ee6e00321549aa.jpg: 640x640 1 Safety Vest, 2 Masks, 1 NO-Mask, 1 Machinery, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/2009_002711_jpg.rf.6fc864b0aeea496698e8d8f650729efa.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 3 NO-Masks, 2 Persons, 2 Machinerys, 3 Vehicles, 7.8ms
# Speed: 1.6ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/2009_002711_jpg.rf.c5342ac0316773ec167d3bc6f61ec8ac.jpg: 640x640 1 NO-Hardhat, 1 NO-Safety Vest, 1 Mask, 2 NO-Masks, 1 Safety Cone, 1 Vehicle, 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/2009_002711_jpg.rf.f0563c83394a79e936b0ecec2658ec97.jpg: 640x640 2 NO-Hardhats, 3 Masks, 4 NO-Masks, 1 Vehicle, 7.9ms
# Speed: 1.6ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/2_jpg.rf.2a2cafa3fd6db594c2f3a46f971b1c14.jpg: 640x640 1 Hardhat, 2 NO-Masks, 1 Safety Cone, 2 Machinerys, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/2_jpg.rf.5d1d2457d0de245aa673442ac06891df.jpg: 640x640 1 Hardhat, 1 Mask, 4 NO-Masks, 2 Safety Cones, 7 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/329_jpg.rf.4a5e5473d213e592580c29c03b2db094.jpg: 640x640 2 Hardhats, 2 NO-Safety Vests, 1 Mask, 3 NO-Masks, 2 Safety Cones, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/405_jpg.rf.d32a5c5e31bf063c660923d082f43e83.jpg: 640x640 2 Hardhats, 1 Safety Vest, 6 NO-Safety Vests, 3 Masks, 7 NO-Masks, 1 Person, 3 Safety Cones, 2 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/4c43875bc97cdaece84ac6ce555235f1_jpg.rf.f0ababbd27b5c11652961e9e5b4da88b.jpg: 640x640 4 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/588_jpg.rf.f4b4ae3e5ee90c957a0b8a62cbd88954.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 2 NO-Masks, 1 Vehicle, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/777_jpg.rf.92dc6945342410ced7ac93f3dfbff0c5.jpg: 640x640 2 Masks, 2 NO-Masks, 1 Person, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Apple-Tests-Face-ID-Feature-While-Wearing-a-Mask-Shorts_mp4-51_jpg.rf.74c8055c0e237b07789f149d71a06444.jpg: 640x640 2 Hardhats, 2 NO-Safety Vests, 5 NO-Masks, 1 Person, 2 Safety Cones, 4 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Apple-Tests-Face-ID-Feature-While-Wearing-a-Mask-Shorts_mp4-51_jpg.rf.c943db9b286389250ee78674432c1ccb.jpg: 640x640 1 Person, 1 Machinery, 1 Vehicle, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Bookstore111_jpg.rf.49397b7bdc4e2a3fa4947b42a57be10e.jpg: 640x640 1 Hardhat, 3 Safety Vests, 1 NO-Safety Vest, 3 Masks, 2 NO-Masks, 9 Persons, 1 Safety Cone, 1 Machinery, 1 Vehicle, 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/IMG_5847_jpg.rf.321a7891cd33cfd8e8ae930563660aac.jpg: 640x640 7 Hardhats, 1 Safety Vest, 7 NO-Safety Vests, 1 Mask, 11 NO-Masks, 8 Safety Cones, 3 Machinerys, 3 Vehicles, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Image_1009_jpg.rf.7e8e17c1edb556205d0418d1e0a29522.jpg: 640x640 1 NO-Mask, 10 Persons, 1 Machinery, 1 Vehicle, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Image_1025_jpg.rf.61268a2f144c707d1190c9370721cb9e.jpg: 640x640 2 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Image_1025_jpg.rf.d305cc24e2ade948caab2bb624791bb4.jpg: 640x640 1 Mask, 2 NO-Masks, 3 Machinerys, 1 Vehicle, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Image_1025_jpg.rf.f4f8eed01172df173ae33e8e0e292a80.jpg: 640x640 1 NO-Hardhat, 2 Safety Vests, 1 Mask, 3 NO-Masks, 4 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Image_1037_jpg.rf.217089bf7b79d7f9ab1e5543954fd72f.jpg: 640x640 3 Hardhats, 1 Safety Vest, 4 NO-Safety Vests, 6 Masks, 7 NO-Masks, 1 Machinery, 7.2ms
# Speed: 1.5ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Image_991_jpg.rf.a52106bd4af0ce8bc49d9b8f6ba5c6c7.jpg: 640x640 3 NO-Masks, 3 Safety Cones, 2 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Image_995_jpg.rf.60c0e78f49bac4cf43c00466d73bbcb7.jpg: 640x640 1 Hardhat, 2 NO-Safety Vests, 3 NO-Masks, 2 Safety Cones, 9 Machinerys, 1 Vehicle, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Inside-merge_mov-16_jpg.rf.7497b66a211972c0baaf43831553d347.jpg: 640x640 1 Hardhat, 1 Safety Vest, 3 NO-Masks, 1 Person, 1 Safety Cone, 1 Machinery, 1 Vehicle, 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Nhh_img_141_jpg.rf.9c0deb5a98f350e6a55e5e0a2baf5b57.jpg: 640x640 1 Safety Vest, 3 Masks, 2 NO-Masks, 3 Machinerys, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/airport_inside_0214_jpg.rf.15a384374cf39042cbdd00d9a0973b36.jpg: 640x640 5 Hardhats, 1 Safety Vest, 2 NO-Safety Vests, 4 Masks, 7 NO-Masks, 4 Machinerys, 4 Vehicles, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/airport_inside_0214_jpg.rf.9b019f9472eb1fe3abc0c60fb3369e67.jpg: 640x640 1 NO-Mask, 2 Machinerys, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/airport_inside_0345_jpg.rf.81733cc3cc37d665aabb9d11122ab053.jpg: 640x640 1 Safety Vest, 1 NO-Safety Vest, 1 Mask, 2 NO-Masks, 4 Persons, 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/airport_inside_0363_jpg.rf.80fddb2e754c830ff538e01dc1366296.jpg: 640x640 1 NO-Mask, 1 Person, 5 Machinerys, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/airport_inside_0460_jpg.rf.08bdc9d5bdd94eda87888c1082b3871f.jpg: 640x640 2 Hardhats, 2 Masks, 2 NO-Masks, 2 Machinerys, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/airport_inside_0460_jpg.rf.aae905a80f304e8b4a3e3c738887490b.jpg: 640x640 5 Hardhats, 1 NO-Safety Vest, 2 Masks, 4 NO-Masks, 2 Safety Cones, 1 Machinery, 1 Vehicle, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/airport_inside_0550_jpg.rf.f2c346802de743043297e70687160686.jpg: 640x640 14 Persons, 1 Machinery, 1 Vehicle, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox4_mp4-111_jpg.rf.007d84ad1f436206297bbc55b174fff9.jpg: 640x640 9 Hardhats, 7 NO-Safety Vests, 2 Masks, 12 NO-Masks, 9 Persons, 12 Safety Cones, 2 Vehicles, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox4_mp4-111_jpg.rf.2292cbeef0a5da66dd9fe1040822d3e9.jpg: 640x640 7 Hardhats, 6 NO-Safety Vests, 1 Mask, 11 NO-Masks, 7 Persons, 9 Safety Cones, 2 Vehicles, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox4_mp4-112_jpg.rf.dfb0c2b0da41e5c1cc6287d06ee92aea.jpg: 640x640 2 Safety Vests, 2 NO-Safety Vests, 2 Masks, 1 NO-Mask, 1 Machinery, 2 Vehicles, 7.8ms
# Speed: 1.6ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox4_mp4-72_jpg.rf.5e9c1836f027bf40eb8898e68f2efdeb.jpg: 640x640 8 Persons, 1 Vehicle, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox5_mp4-34_jpg.rf.e0c7d0632b6b6ec9aae7b89a2b096bea.jpg: 640x640 1 Person, 4 Machinerys, 1 Vehicle, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox6_mp4-157_jpg.rf.0bb6fec008de80af30afd18d1a6c676f.jpg: 640x640 1 Safety Vest, 2 NO-Safety Vests, 2 Masks, 3 NO-Masks, 5 Persons, 4 Machinerys, 4 Vehicles, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox6_mp4-20_jpg.rf.2ea83677536cb5929e57581ab983827b.jpg: 640x640 1 Hardhat, 1 Safety Vest, 1 NO-Safety Vest, 2 NO-Masks, 3 Persons, 2 Safety Cones, 1 Machinery, 2 Vehicles, 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox6_mp4-20_jpg.rf.ba6134721c0c752e7142a6299d2f04e9.jpg: 640x640 3 Safety Vests, 2 NO-Safety Vests, 3 Masks, 3 NO-Masks, 3 Persons, 1 Machinery, 1 Vehicle, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1-_mp4-115_jpg.rf.2aa43302e55d176724bc0d99dcea9663.jpg: 640x640 1 Hardhat, 1 Safety Vest, 2 NO-Masks, 4 Machinerys, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1-_mp4-115_jpg.rf.3180062637f2f2c6dac5a1a773a3d006.jpg: 640x640 1 Hardhat, 1 NO-Mask, 4 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1-_mp4-60_jpg.rf.30b09a8c2865e4922520e7d022dd9c61.jpg: 640x640 2 Hardhats, 1 Safety Vest, 1 NO-Safety Vest, 2 NO-Masks, 1 Safety Cone, 1 Machinery, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1-_mp4-60_jpg.rf.645d185e1b6e0050a5c70dbd2136824c.jpg: 640x640 4 Hardhats, 1 Safety Vest, 3 NO-Safety Vests, 2 Masks, 5 NO-Masks, 3 Safety Cones, 2 Machinerys, 3 Vehicles, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1-_mp4-60_jpg.rf.73ba97ab2f23c2ef4776160a27424f5a.jpg: 640x640 1 NO-Mask, 2 Persons, 3 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1-_mp4-64_jpg.rf.92efd1b50f4e66f245f5705e2d6b7342.jpg: 640x640 5 Hardhats, 4 NO-Safety Vests, 4 Masks, 5 NO-Masks, 2 Machinerys, 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1015-_jpg.rf.9e94d76133793a7dfe1aeb00e6ecd373.jpg: 640x640 1 NO-Hardhat, 1 Mask, 1 NO-Mask, 2 Machinerys, 1 Vehicle, 7.6ms
# Speed: 1.4ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1023-_jpg.rf.7b73352606fb1d79619d34031c07a232.jpg: 640x640 2 Machinerys, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1027-_jpg.rf.e78f55761814a8726ea51993407957af.jpg: 640x640 2 Machinerys, 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1029-_jpg.rf.4b275026c8888b66ce2694d2dda856c3.jpg: 640x640 1 Hardhat, 1 NO-Hardhat, 1 Safety Vest, 2 NO-Safety Vests, 3 Masks, 3 NO-Masks, 2 Machinerys, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1029-_jpg.rf.99a91e79d6e2bf58dc80922f7d7c3adf.jpg: 640x640 10 Hardhats, 2 NO-Hardhats, 8 NO-Safety Vests, 1 Mask, 10 NO-Masks, 10 Safety Cones, 1 Machinery, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1029-_jpg.rf.e40ed9707d9ea79a66586b7eafe0ae52.jpg: 640x640 2 NO-Hardhats, 2 Safety Vests, 1 Mask, 2 NO-Masks, 2 Machinerys, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1029-_jpg.rf.f34331d792a26cbe94ef77e3251989ac.jpg: 640x640 1 NO-Hardhat, 1 Mask, 2 NO-Masks, 1 Machinery, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1037-_jpg.rf.c44151f7f28c4da9757409953b1bff55.jpg: 640x640 2 Machinerys, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1062-_jpg.rf.30c06a00f2aef933ecf9aaa4b95f1320.jpg: 640x640 3 Hardhats, 1 Safety Vest, 2 NO-Safety Vests, 2 Masks, 4 NO-Masks, 1 Machinery, 1 Vehicle, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1099-_jpg.rf.df1d160085e954901f2efa84fd4a2e91.jpg: 640x640 1 NO-Hardhat, 1 Mask, 1 NO-Mask, 3 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1099-_jpg.rf.feeacd8e655f29f874d6bf1ae57cf022.jpg: 640x640 2 Hardhats, 1 NO-Hardhat, 1 NO-Safety Vest, 3 Masks, 4 NO-Masks, 1 Machinery, 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1115-_jpg.rf.65aea4ef94ae0c57a90b44eb2056a940.jpg: 640x640 6 Hardhats, 2 Safety Vests, 5 NO-Safety Vests, 4 Masks, 5 NO-Masks, 1 Machinery, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1116-_jpg.rf.293365d3885eed0bcae63201c5ca15f6.jpg: 640x640 2 NO-Masks, 2 Safety Cones, 3 Machinerys, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1116-_jpg.rf.89204e926b55ec2da9541d47c0b88309.jpg: 640x640 1 NO-Hardhat, 2 Masks, 1 NO-Mask, 2 Machinerys, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1116-_jpg.rf.d86e88d4a8ced388b86abff05c5aeefe.jpg: 640x640 1 NO-Safety Vest, 2 NO-Masks, 2 Machinerys, 1 Vehicle, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1116-_jpg.rf.da7f8f05689a5daf50a70fd109bb4a8f.jpg: 640x640 2 Machinerys, 8.8ms
# Speed: 2.1ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-112-_jpg.rf.699d3c5a3155bb76ee6e10e842cc24de.jpg: 640x640 1 NO-Safety Vest, 1 Mask, 2 NO-Masks, 1 Machinery, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-112-_jpg.rf.aff73a376ef301a11e45c58fb084e7a5.jpg: 640x640 1 NO-Mask, 1 Safety Cone, 4 Machinerys, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1159-_jpg.rf.9f3172102a34edb157b556a73931c831.jpg: 640x640 1 Machinery, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-196-_jpg.rf.f593da25134315b48b325fb42436a01a.jpg: 640x640 1 Machinery, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-113_jpg.rf.657cf7274654eddca1d6c542cdee3dd0.jpg: 640x640 1 NO-Hardhat, 2 Safety Vests, 3 NO-Masks, 5 Persons, 2 Machinerys, 1 Vehicle, 7.2ms
# Speed: 1.5ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-113_jpg.rf.b9c7bbcaf17702d65b9cccb60a39bb47.jpg: 640x640 3 Hardhats, 2 NO-Safety Vests, 2 Masks, 3 NO-Masks, 10 Persons, 1 Machinery, 1 Vehicle, 6.9ms
# Speed: 1.4ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-12_jpg.rf.08cddb92471bc97a4bb37b6ce28b5655.jpg: 640x640 1 NO-Mask, 3 Machinerys, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-13_jpg.rf.cef0975976346515d438e0c2ce6c59db.jpg: 640x640 3 Machinerys, 6.9ms
# Speed: 1.4ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-15_jpg.rf.94d743aaa79935634d2cc4ea6a5bfe2c.jpg: 640x640 2 Hardhats, 1 NO-Hardhat, 2 Safety Vests, 3 NO-Safety Vests, 1 Mask, 5 NO-Masks, 1 Safety Cone, 2 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-15_jpg.rf.a5fa6e719e0427f773a54c8d4cc19a1d.jpg: 640x640 2 NO-Hardhats, 1 Mask, 2 NO-Masks, 1 Safety Cone, 3 Machinerys, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-178_jpg.rf.0b86b7829e2da46f66cbf5dddb677a82.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 1 NO-Mask, 4 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-178_jpg.rf.7cea31ac9f8ab023bd65a904607a3d06.jpg: 640x640 1 Hardhat, 2 NO-Hardhats, 1 Safety Vest, 1 NO-Safety Vest, 2 Masks, 3 NO-Masks, 1 Safety Cone, 2 Machinerys, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-210_jpg.rf.2499564f33bc763f58c65a576f4afdd0.jpg: 640x640 2 Hardhats, 2 NO-Safety Vests, 1 Mask, 2 NO-Masks, 1 Safety Cone, 3 Machinerys, 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-213_jpg.rf.3dc254f0ee3f229e0766837fcb916d24.jpg: 640x640 2 NO-Masks, 5 Machinerys, 6 Vehicles, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-213_jpg.rf.796b34b4516cfb4f1aefddbb912f01b5.jpg: 640x640 2 NO-Hardhats, 1 Safety Vest, 2 Masks, 2 NO-Masks, 1 Machinery, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-219_jpg.rf.0ad7ddf87079cf198c8d4c90fb679f49.jpg: 640x640 1 NO-Hardhat, 1 Mask, 1 NO-Mask, 2 Persons, 1 Machinery, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-219_jpg.rf.d00dcbb1681782b09b105dd0c54d5852.jpg: 640x640 2 Hardhats, 3 NO-Hardhats, 1 Safety Vest, 1 Mask, 3 NO-Masks, 2 Safety Cones, 2 Machinerys, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-219_jpg.rf.dae32347bb4fed1d2078263a64f58a70.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 NO-Safety Vest, 2 Masks, 3 NO-Masks, 1 Safety Cone, 1 Machinery, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-207-_jpg.rf.67da281e0dc359a3d8e0ff40b561dfac.jpg: 640x640 1 NO-Hardhat, 1 Mask, 1 NO-Mask, 3 Machinerys, 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-212-_jpg.rf.276f0a7fdf6fca4c0c75a1d69c095c28.jpg: 640x640 1 NO-Safety Vest, 2 NO-Masks, 3 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-212-_jpg.rf.dfc3cd38ed63f7b7f642f8b1cbb1b68e.jpg: 640x640 4 Machinerys, 8.5ms
# Speed: 1.6ms preprocess, 8.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-253-_jpg.rf.0590780a5e0f86c9f306c71d7c3a3c6b.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 2 NO-Masks, 1 Machinery, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-260-_jpg.rf.b8584809048dd6843855f0f8c5b0a7a9.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 2 NO-Masks, 1 Safety Cone, 3 Machinerys, 7.7ms
# Speed: 1.6ms preprocess, 7.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-260-_jpg.rf.bed6cb4622027ec2bf56e6e5f0e8b2cc.jpg: 640x640 1 Mask, 1 NO-Mask, 5 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-267-_jpg.rf.222246f7ce5e3109de00144c4f603292.jpg: 640x640 2 NO-Hardhats, 2 Masks, 2 NO-Masks, 3 Machinerys, 3 Vehicles, 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-267-_jpg.rf.36fd4d82d55aa7d307deccc95bb1b68e.jpg: 640x640 1 Hardhat, 2 Safety Vests, 1 NO-Safety Vest, 3 Masks, 4 NO-Masks, 1 Safety Cone, 1 Machinery, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-267-_jpg.rf.5c65fe4e77d4493d6788f644468d3939.jpg: 640x640 2 NO-Masks, 1 Safety Cone, 9 Machinerys, 4 Vehicles, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-274-_jpg.rf.21181010ffb2b9ea429080ccd258e3ae.jpg: 640x640 2 Machinerys, 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-275-_jpg.rf.e1c57987f9dc262aad1d7c67b694fd87.jpg: 640x640 1 Machinery, 7.4ms
# Speed: 1.5ms preprocess, 7.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-277-_jpg.rf.bf73a4edc7a1f7d412bc3267cbafcda7.jpg: 640x640 1 Machinery, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-122_jpg.rf.0cd1654e69130f2f2b2b5adb08c879f0.jpg: 640x640 2 Hardhats, 3 NO-Masks, 5 Machinerys, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-122_jpg.rf.7bb280627f23963d8fc187e624716358.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 1 NO-Mask, 5 Machinerys, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-148_jpg.rf.20ec335e8625ddb4da3d7d656718c1bd.jpg: 640x640 1 Hardhat, 2 NO-Masks, 3 Machinerys, 7.8ms
# Speed: 1.6ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-162_jpg.rf.52db765af29c85fdf701e0d4a7624fb4.jpg: 640x640 2 NO-Masks, 2 Safety Cones, 3 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-162_jpg.rf.9029ca82bb02bc31a4768f0f3e3655e4.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 NO-Mask, 1 Machinery, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-162_jpg.rf.d5b9deac1a1c1205d223e3d604afdd09.jpg: 640x640 1 Hardhat, 2 Safety Vests, 1 NO-Safety Vest, 5 Masks, 5 NO-Masks, 3 Machinerys, 1 Vehicle, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-162_jpg.rf.fcc17856f133926e2b49c657efcd48be.jpg: 640x640 3 NO-Masks, 6 Persons, 1 Machinery, 2 Vehicles, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-166_jpg.rf.3785bac9c8d14230444b9d7b9e669987.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 NO-Mask, 8 Persons, 2 Machinerys, 2 Vehicles, 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-211_jpg.rf.7a50e0bbc5b5dcf920cbd67eeaa0c576.jpg: 640x640 1 Mask, 2 NO-Masks, 5 Persons, 6 Machinerys, 1 Vehicle, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-21_jpg.rf.4fc9ff5afc8387b5c673a424781c527c.jpg: 640x640 1 Mask, 1 NO-Mask, 2 Machinerys, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-67_jpg.rf.2ac209d6daf4ac7a4247a4ee28385fe8.jpg: 640x640 1 Hardhat, 1 Safety Vest, 2 NO-Safety Vests, 3 NO-Masks, 2 Safety Cones, 2 Machinerys, 1 Vehicle, 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-305-_jpg.rf.d6bf62f198a43cec387208b956a3c8f7.jpg: 640x640 3 Hardhats, 3 Masks, 7 NO-Masks, 2 Safety Cones, 6 Machinerys, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-331-_jpg.rf.ea29c106612a81b5265ea538ee457638.jpg: 640x640 1 Hardhat, 1 NO-Mask, 5 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-347-_jpg.rf.019a625d11ee3deb1aae360a2755d707.jpg: 640x640 13 Hardhats, 7 NO-Safety Vests, 15 NO-Masks, 13 Safety Cones, 1 Machinery, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-347-_jpg.rf.da66417ec4dc8d612f5613fa67c262c7.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 2 NO-Masks, 1 Safety Cone, 1 Machinery, 3 Vehicles, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-347-_jpg.rf.f5e15e0e36d3cc7fcfbf49d68c21f121.jpg: 640x640 1 NO-Safety Vest, 2 Masks, 2 NO-Masks, 8 Persons, 1 Machinery, 1 Vehicle, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-369-_jpg.rf.23dd790f943919d62800543641ea8474.jpg: 640x640 1 Hardhat, 1 NO-Hardhat, 1 Safety Vest, 2 NO-Safety Vests, 1 Mask, 3 NO-Masks, 1 Safety Cone, 2 Machinerys, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-369-_jpg.rf.27b76b8bb58e9f12d60cb654abdbf508.jpg: 640x640 1 Mask, 2 NO-Masks, 5 Machinerys, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-369-_jpg.rf.30fa5e9b5231010dabadf061d2db52d3.jpg: 640x640 2 NO-Hardhats, 1 Safety Vest, 2 Masks, 4 NO-Masks, 2 Machinerys, 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-385-_jpg.rf.9f93c4ac5c55c8d091e71d7820d964c2.jpg: 640x640 1 NO-Mask, 2 Machinerys, 8.7ms
# Speed: 2.1ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-127_jpg.rf.369dffc6c0812c73e687686e68e9bde3.jpg: 640x640 1 NO-Hardhat, 1 Mask, 3 NO-Masks, 1 Safety Cone, 4 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-127_jpg.rf.c8b5b8cd660a766336ecfcf953fe4305.jpg: 640x640 1 Safety Vest, 1 Mask, 1 NO-Mask, 3 Machinerys, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-165_jpg.rf.245a89fb6862ed44d8698e334777bc6d.jpg: 640x640 4 Machinerys, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-165_jpg.rf.5354cc400c056d38d93601f5e246639a.jpg: 640x640 2 NO-Hardhats, 1 Safety Vest, 3 NO-Safety Vests, 4 Masks, 6 NO-Masks, 3 Safety Cones, 2 Machinerys, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-182_jpg.rf.492a9e7be9451e34149bcbcb89c11810.jpg: 640x640 1 Safety Vest, 1 NO-Safety Vest, 3 NO-Masks, 1 Safety Cone, 5 Machinerys, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-182_jpg.rf.627a7713bb1819c97760a93546151040.jpg: 640x640 1 NO-Hardhat, 1 NO-Safety Vest, 2 Masks, 5 NO-Masks, 1 Safety Cone, 3 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-182_jpg.rf.de6b154c40fe604072fbd94399a9328a.jpg: 640x640 2 Hardhats, 1 Safety Vest, 2 NO-Safety Vests, 3 Masks, 3 NO-Masks, 2 Machinerys, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-182_jpg.rf.f72c3426b5e987bc41302d8309dcc192.jpg: 640x640 6 Machinerys, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-185_jpg.rf.2f9a20acb20029a8d99caf5f3b76e0b3.jpg: 640x640 1 NO-Mask, 6 Machinerys, 1 Vehicle, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-188_jpg.rf.222a8ed73f017be9b2c3fb6c9e250bca.jpg: 640x640 2 Safety Vests, 2 NO-Safety Vests, 5 Masks, 6 NO-Masks, 2 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-188_jpg.rf.74d1b2d1747d25f44bf4d2c8f1fee247.jpg: 640x640 1 Safety Vest, 1 NO-Safety Vest, 2 Masks, 2 NO-Masks, 4 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-188_jpg.rf.b432a7682ba15224171e52a9c7d30a71.jpg: 640x640 2 Hardhats, 1 NO-Safety Vest, 2 NO-Masks, 6 Persons, 1 Safety Cone, 1 Machinery, 1 Vehicle, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-189_jpg.rf.f2e4339a999eb718ff43ad57e06b4da6.jpg: 640x640 1 Mask, 1 NO-Mask, 14 Persons, 1 Machinery, 2 Vehicles, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-19_jpg.rf.ae9b311efa6de4566e5c8ec20c3718fb.jpg: 640x640 1 NO-Mask, 1 Person, 2 Machinerys, 2 Vehicles, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-19_jpg.rf.b39073990b499b99dfe415a49fdb90bb.jpg: 640x640 2 Machinerys, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-38_jpg.rf.2e5287c7925dbf5a8ef8422c0e6fee27.jpg: 640x640 3 Masks, 2 NO-Masks, 7 Persons, 4 Machinerys, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-41_jpg.rf.52ca8fcab8ce72c4dee7fefc91681934.jpg: 640x640 1 Hardhat, 1 NO-Hardhat, 1 Safety Vest, 2 NO-Safety Vests, 2 Masks, 3 NO-Masks, 1 Safety Cone, 2 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-41_jpg.rf.c5e4bcc5976beec3e62122474353665b.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 1 Mask, 1 NO-Mask, 1 Machinery, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-89_jpg.rf.bfb1483dd3989a71df592291d66d94fe.jpg: 640x640 4 NO-Hardhats, 1 Safety Vest, 1 NO-Mask, 3 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-94_jpg.rf.af104684c19a232f02c90552eaa84fbc.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 2 Masks, 2 NO-Masks, 3 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-94_jpg.rf.ed816f287bc4996348f474833197cdc0.jpg: 640x640 1 Safety Vest, 1 Mask, 2 NO-Masks, 3 Machinerys, 1 Vehicle, 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-94_jpg.rf.faa54990813350bf15eebdb3d1ace03d.jpg: 640x640 18 Hardhats, 17 NO-Safety Vests, 13 NO-Masks, 19 Safety Cones, 3 Machinerys, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-434-_jpg.rf.08f3862f335fb52c0e87c4664d373751.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 NO-Safety Vest, 2 Masks, 2 NO-Masks, 2 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-136_jpg.rf.3f565846fbd70422e73d09aab8c2c2b4.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 2 NO-Masks, 4 Machinerys, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-136_jpg.rf.4de970ffc60aa2cda3fb97f03350384a.jpg: 640x640 2 Hardhats, 1 NO-Hardhat, 4 Safety Vests, 6 NO-Safety Vests, 3 Masks, 6 NO-Masks, 3 Safety Cones, 1 Machinery, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-136_jpg.rf.5781617c5a56e26adb37b2889ca6a0b8.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 NO-Mask, 12 Persons, 1 Machinery, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-136_jpg.rf.61f13f9398c539e73446daa76339f1dc.jpg: 640x640 1 NO-Hardhat, 1 NO-Mask, 3 Machinerys, 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-136_jpg.rf.aeb3616a8195ab797c209691b9440b21.jpg: 640x640 2 Machinerys, 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-29_jpg.rf.3aa8761e72a2a70eaae36cc6215f9618.jpg: 640x640 9 Persons, 5 Machinerys, 2 Vehicles, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-29_jpg.rf.3ab6fb82c7b98c1cdb491e40508707a8.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 4 Masks, 4 NO-Masks, 2 Machinerys, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-29_jpg.rf.b3d72d5b8af0726c69bd9a4387dcc631.jpg: 640x640 1 NO-Mask, 3 Machinerys, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-30_jpg.rf.527821dcd495003327e1d90baeb2f8d3.jpg: 640x640 1 Safety Vest, 1 NO-Safety Vest, 2 NO-Masks, 1 Person, 2 Safety Cones, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-39_jpg.rf.e828d532dce99528cc3afc47a75b6c29.jpg: 640x640 3 NO-Masks, 3 Safety Cones, 3 Machinerys, 1 Vehicle, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-48_jpg.rf.4fdbba397c6dbde429373640d634e935.jpg: 640x640 1 Hardhat, 2 NO-Masks, 2 Machinerys, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-48_jpg.rf.82ca9f1ab7f0394a237c4938bdd913f9.jpg: 640x640 1 NO-Mask, 4 Machinerys, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-48_jpg.rf.869646c7e34f2451c66b6d9487b68281.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 1 Mask, 2 NO-Masks, 4 Machinerys, 6.6ms
# ...
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-464_jpg.rf.355495bd54c66f71e909fa906b77e184.jpg: 640x640 3 Hardhats, 2 NO-Safety Vests, 3 NO-Masks, 3 Safety Cones, 2 Machinerys, 2 Vehicles, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-464_jpg.rf.8784a32dc660e889975cf6d6065c469a.jpg: 640x640 1 Hardhat, 1 NO-Mask, 23 Persons, 1 Safety Cone, 2 Machinerys, 2 Vehicles, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-471_jpg.rf.4296b7bd9a5a07753077beddbcd651bf.jpg: 640x640 1 NO-Mask, 1 Safety Cone, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-474_jpg.rf.a69f31210940425bb2099ce9f6683645.jpg: 640x640 1 Hardhat, 2 NO-Safety Vests, 2 NO-Masks, 2 Safety Cones, 1 Machinery, 1 Vehicle, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-497_jpg.rf.b8b5f459b6bf69cc2383c6f8f7de916d.jpg: 640x640 1 Safety Vest, 4 NO-Masks, 3 Machinerys, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-497_jpg.rf.de718ed675c4ac0cb19ccccac738aeb2.jpg: 640x640 1 Hardhat, 1 Safety Vest, 2 NO-Masks, 2 Machinerys, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-49_jpg.rf.5a44fe43dd47987a1b67b83e743ea9ce.jpg: 640x640 1 Safety Vest, 1 NO-Safety Vest, 2 Masks, 2 NO-Masks, 2 Machinerys, 1 Vehicle, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-506_jpg.rf.f6eb407abb8cd008124e1178d332a64b.jpg: 640x640 4 Hardhats, 5 Safety Vests, 3 NO-Safety Vests, 4 Masks, 7 NO-Masks, 3 Safety Cones, 2 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-507_jpg.rf.9dd5d0a2881420c1b72fa4749c1d8830.jpg: 640x640 1 Hardhat, 2 Safety Vests, 1 NO-Safety Vest, 2 NO-Masks, 1 Safety Cone, 2 Machinerys, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-507_jpg.rf.a859758779df04ea778068a73b402d3c.jpg: 640x640 1 Hardhat, 2 NO-Hardhats, 3 Safety Vests, 2 NO-Safety Vests, 2 Masks, 4 NO-Masks, 2 Safety Cones, 1 Machinery, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-550_jpg.rf.0a199dbd9cdb73adb689576c257cd853.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 1 NO-Mask, 11 Machinerys, 2 Vehicles, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-554_jpg.rf.12abc545630972a6e272892494a59dcc.jpg: 640x640 1 Hardhat, 1 NO-Hardhat, 1 Safety Vest, 2 NO-Safety Vests, 2 Masks, 5 NO-Masks, 1 Person, 1 Safety Cone, 2 Machinerys, 2 Vehicles, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-554_jpg.rf.7c697c7deea9995a0145e96cb7a23797.jpg: 640x640 1 NO-Hardhat, 1 Mask, 2 NO-Masks, 5 Machinerys, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-560_jpg.rf.8f99653f70bc2287a75c70758e5a43e0.jpg: 640x640 4 Hardhats, 5 NO-Safety Vests, 5 Masks, 7 NO-Masks, 2 Safety Cones, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-564_jpg.rf.4d53a205cd034c39472c8ceebf3af69d.jpg: 640x640 1 NO-Hardhat, 1 NO-Mask, 1 Safety Cone, 1 Machinery, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-571_jpg.rf.445722ace33f1fd733756c215912b3a8.jpg: 640x640 1 Hardhat, 2 NO-Masks, 2 Safety Cones, 2 Machinerys, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-571_jpg.rf.d380c7fde4b25c50887691ab5d5dcfac.jpg: 640x640 2 Hardhats, 3 NO-Hardhats, 2 NO-Safety Vests, 4 NO-Masks, 2 Safety Cones, 1 Machinery, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-574_jpg.rf.3e198affe680e93fff82325572cc6972.jpg: 640x640 4 NO-Masks, 2 Safety Cones, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-574_jpg.rf.ec53f3e134d613ec561e1f7fb9e56db2.jpg: 640x640 7 Hardhats, 4 NO-Safety Vests, 8 NO-Masks, 7 Safety Cones, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-579_jpg.rf.db114ff0f07961521749739faca4fbcb.jpg: 640x640 1 Hardhat, 3 NO-Masks, 3 Safety Cones, 1 Machinery, 2 Vehicles, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-57_jpg.rf.87a1f2203f761f29bdf0543239ec739d.jpg: 640x640 9 Persons, 2 Machinerys, 3 Vehicles, 7.4ms
# Speed: 1.7ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-615_jpg.rf.7f41bbb94234c00582504401d4a76a60.jpg: 640x640 1 Mask, 4 NO-Masks, 1 Person, 2 Safety Cones, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-641_jpg.rf.aa36d0a940f13bcbd69f98d5309960b4.jpg: 640x640 2 NO-Safety Vests, 1 Mask, 3 NO-Masks, 1 Safety Cone, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-641_jpg.rf.f8e9bcb9a5aba1a0fab955a47ea38760.jpg: 640x640 1 Hardhat, 3 Safety Vests, 2 NO-Safety Vests, 4 Masks, 6 NO-Masks, 1 Safety Cone, 1 Machinery, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-645_jpg.rf.0cae206994074c96880eee9f8b4f6fa0.jpg: 640x640 2 Hardhats, 2 NO-Safety Vests, 3 Masks, 2 NO-Masks, 3 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-645_jpg.rf.678dd020ed3048e268f7768a6df08cf8.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 NO-Mask, 1 Machinery, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-661_jpg.rf.96b27bc1550d9c74255de3061c1d61cb.jpg: 640x640 1 NO-Mask, 3 Persons, 3 Vehicles, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-667_jpg.rf.8c29596b7486388ed0cdf3da93f73cd4.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 1 NO-Mask, 2 Machinerys, 3 Vehicles, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-668_jpg.rf.179b654b1f4c6574010186dd4fbdd475.jpg: 640x640 1 NO-Mask, 1 Person, 1 Machinery, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-668_jpg.rf.4aa90caeca7a6635021aea2a4f3ccf13.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 1 Mask, 2 NO-Masks, 1 Safety Cone, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-668_jpg.rf.ce3804ef6c8f28490efeb8d2b5d52090.jpg: 640x640 2 NO-Hardhats, 1 NO-Mask, 1 Safety Cone, 1 Vehicle, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-693_jpg.rf.1fe523c5b5c19d9b16bfb8b8a20fb29f.jpg: 640x640 1 Mask, 1 NO-Mask, 2 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-695_jpg.rf.19a86e22fe4a33c49cba7546d5e6498d.jpg: 640x640 4 Hardhats, 5 NO-Safety Vests, 1 Mask, 7 NO-Masks, 7 Safety Cones, 1 Machinery, 3 Vehicles, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-699_jpg.rf.ced94dd4765a8ff9fe60e7648179fb6d.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 2 NO-Masks, 1 Person, 2 Safety Cones, 3 Machinerys, 2 Vehicles, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-726_jpg.rf.7ca57d637c5acb0d2772e0815a6d80e3.jpg: 640x640 1 NO-Mask, 2 Machinerys, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-726_jpg.rf.9217e70297b89a7a06e94a1432196d79.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 2 Masks, 4 NO-Masks, 2 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-730_jpg.rf.26bec93a311351ca9c06119164ef8de5.jpg: 640x640 1 Safety Vest, 3 NO-Masks, 3 Safety Cones, 1 Machinery, 3 Vehicles, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-730_jpg.rf.b55e41b07155a1b30073fb0e4da9e1b7.jpg: 640x640 4 NO-Hardhats, 3 Safety Vests, 3 Masks, 2 NO-Masks, 1 Safety Cone, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-731_jpg.rf.47b70ce0a8b8a93aca5916119175a04c.jpg: 640x640 1 Hardhat, 2 NO-Safety Vests, 1 Mask, 3 NO-Masks, 2 Safety Cones, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-806_jpg.rf.c8952e265f0c4af327b56f43b365537a.jpg: 640x640 1 NO-Mask, 1 Person, 1 Safety Cone, 1 Machinery, 1 Vehicle, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-809_jpg.rf.6fb92c2982d1c552da9c5ba10ff72d5e.jpg: 640x640 11 Persons, 1 Machinery, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-812_jpg.rf.a5f34a08b407b48f43169f49917906a2.jpg: 640x640 1 NO-Hardhat, 2 Safety Vests, 2 NO-Masks, 1 Machinery, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-813_jpg.rf.63b422efff31ad667fbb228d39e0a2eb.jpg: 640x640 1 Hardhat, 1 NO-Hardhat, 1 NO-Safety Vest, 1 Mask, 2 NO-Masks, 1 Person, 1 Safety Cone, 1 Vehicle, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-813_jpg.rf.b9c7825c3711b9f313376a12b75553f3.jpg: 640x640 2 Hardhats, 1 NO-Hardhat, 1 Safety Vest, 1 NO-Safety Vest, 3 NO-Masks, 2 Persons, 2 Safety Cones, 3 Vehicles, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-813_jpg.rf.f0b08055ea368a39e7846182b7af0102.jpg: 640x640 2 Hardhats, 2 NO-Safety Vests, 4 NO-Masks, 4 Safety Cones, 2 Vehicles, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-815_jpg.rf.efcb04fd1022521a86e34b4fde943808.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 NO-Safety Vest, 2 NO-Masks, 1 Person, 1 Safety Cone, 4 Vehicles, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-837_jpg.rf.1c9fe1c871e46ff877c1f2b443576319.jpg: 640x640 1 Hardhat, 1 Safety Vest, 1 NO-Safety Vest, 4 NO-Masks, 1 Person, 2 Safety Cones, 1 Machinery, 1 Vehicle, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-848_jpg.rf.420254c4553963c6c3d957e2cc961a34.jpg: 640x640 1 Hardhat, 1 Safety Vest, 1 NO-Safety Vest, 2 Masks, 4 NO-Masks, 1 Person, 1 Safety Cone, 2 Machinerys, 2 Vehicles, 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-848_jpg.rf.bef04dc9e34440277e80f82cbdce6e8a.jpg: 640x640 1 Hardhat, 2 NO-Safety Vests, 2 NO-Masks, 1 Person, 1 Safety Cone, 2 Machinerys, 1 Vehicle, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-849_jpg.rf.dfaabf6f93250fdbe0809582859b6397.jpg: 640x640 1 Hardhat, 1 Mask, 4 NO-Masks, 2 Persons, 1 Safety Cone, 4 Machinerys, 3 Vehicles, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ✓ Inference complete!
# Total Detections: 4674
#
# Detection Statistics by Class:
# ============================================================
# class_name
# NO-Mask           1139
# Machinery          933
# Mask               423
# Safety Cone        418
# Hardhat            414
# NO-Safety Vest     371
# Person             366
# Safety Vest        234
# Vehicle            225
# NO-Hardhat         151
# ============================================================

# %% [markdown]
# ## Test Predictions Visualization
#
# Visual inspection of model predictions showing bounding boxes with confidence scores. This helps identify systematic errors or classes the model struggles with.

# %%
# Function to draw predictions on images
def draw_predictions(image_path, results):
    """
    Draw bounding boxes, labels, and confidence scores on image

    Args:
        image_path: Path to the image file
        results: YOLOv8 inference results

    Returns:
        Annotated image in RGB format
    """
    img = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    for result in results:
        for box in result.boxes:
            class_id = int(box.cls)
            confidence = float(box.conf)

            x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())

            color = class_colors.get(class_id, (255, 255, 255))
            cv2.rectangle(img_rgb, (x1, y1), (x2, y2), color, 2)

            label = f"{ppe_classes[class_id]}: {confidence:.2f}"
            cv2.putText(img_rgb, label, (x1, y1 - 10),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

    return img_rgb

# Visualize predictions on test set
fig, axes = plt.subplots(4, 4, figsize=(18, 16))
fig.suptitle('YOLOv8 Predictions on Test Set with Confidence Scores',
             fontsize=14, fontweight='bold')

for idx, img_path in enumerate(test_images[:16]):
    row = idx // 4
    col = idx % 4

    results = model(str(img_path), conf=0.25, iou=0.45)
    pred_img = draw_predictions(str(img_path), results)

    axes[row, col].imshow(pred_img)
    axes[row, col].set_title(f'{img_path.name}', fontsize=8)
    axes[row, col].axis('off')

plt.tight_layout()
plt.savefig('test_predictions.png', dpi=150, bbox_inches='tight')
plt.show()

print("✓ Test predictions visualized and saved as 'test_predictions.png'")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Confidence Threshold Analysis
#
# Testing different confidence thresholds to understand the precision-recall trade-off for deployment decisions.
#
# **Lower thresholds** → More detections (catches more objects) but more false positives
# **Higher thresholds** → Fewer detections (misses more objects) but higher accuracy on what it does detect

# %%
# Analyze impact of confidence thresholds
confidence_thresholds = [0.1, 0.25, 0.5, 0.75]
threshold_stats = []

print("Analyzing confidence thresholds...")
print("=" * 60)

for conf_thresh in confidence_thresholds:
    total_detections = 0
    confidences = []

    for img_path in test_images:
        results = model(str(img_path), conf=conf_thresh, iou=0.45)
        for result in results:
            total_detections += len(result.boxes)
            for box in result.boxes:
                confidences.append(float(box.conf))

    threshold_stats.append({
        'Confidence Threshold': f'{conf_thresh:.2f}',
        'Total Detections': total_detections,
        'Avg Confidence': np.mean(confidences) if confidences else 0,
        'Min Confidence': np.min(confidences) if confidences else 0
    })

threshold_df = pd.DataFrame(threshold_stats)
print("Confidence Threshold Analysis:")
print(threshold_df.to_string(index=False))
print("=" * 60)

# Visualize threshold impact
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(threshold_df['Confidence Threshold'], threshold_df['Total Detections'],
       color='steelblue', alpha=0.7, edgecolor='black')
ax.set_xlabel('Confidence Threshold', fontsize=11)
ax.set_ylabel('Number of Detections', fontsize=11)
ax.set_title('Detection Count vs Confidence Threshold', fontsize=12, fontweight='bold')
ax.grid(alpha=0.3, axis='y')

# Add value labels on bars
for i, v in enumerate(threshold_df['Total Detections']):
    ax.text(i, v + 10, str(v), ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.savefig('confidence_threshold_analysis.png', dpi=150, bbox_inches='tight')
plt.show()

print("✓ Confidence threshold analysis visualized and saved")
# Out:
# Streaming output truncated to the last 5000 lines.
# Speed: 1.6ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Image_1037_jpg.rf.217089bf7b79d7f9ab1e5543954fd72f.jpg: 640x640 3 Hardhats, 2 Safety Vests, 4 NO-Safety Vests, 6 Masks, 8 NO-Masks, 1 Machinery, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Image_991_jpg.rf.a52106bd4af0ce8bc49d9b8f6ba5c6c7.jpg: 640x640 3 NO-Masks, 3 Safety Cones, 2 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Image_995_jpg.rf.60c0e78f49bac4cf43c00466d73bbcb7.jpg: 640x640 1 Hardhat, 2 NO-Safety Vests, 2 Masks, 4 NO-Masks, 2 Safety Cones, 11 Machinerys, 2 Vehicles, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Inside-merge_mov-16_jpg.rf.7497b66a211972c0baaf43831553d347.jpg: 640x640 1 Hardhat, 1 Safety Vest, 3 NO-Masks, 1 Person, 1 Safety Cone, 1 Machinery, 1 Vehicle, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/Nhh_img_141_jpg.rf.9c0deb5a98f350e6a55e5e0a2baf5b57.jpg: 640x640 2 Safety Vests, 3 Masks, 2 NO-Masks, 3 Machinerys, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/airport_inside_0214_jpg.rf.15a384374cf39042cbdd00d9a0973b36.jpg: 640x640 8 Hardhats, 1 Safety Vest, 2 NO-Safety Vests, 6 Masks, 10 NO-Masks, 4 Machinerys, 6 Vehicles, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/airport_inside_0214_jpg.rf.9b019f9472eb1fe3abc0c60fb3369e67.jpg: 640x640 2 NO-Masks, 1 Safety Cone, 2 Machinerys, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/airport_inside_0345_jpg.rf.81733cc3cc37d665aabb9d11122ab053.jpg: 640x640 1 Safety Vest, 1 NO-Safety Vest, 2 Masks, 2 NO-Masks, 4 Persons, 1 Machinery, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/airport_inside_0363_jpg.rf.80fddb2e754c830ff538e01dc1366296.jpg: 640x640 1 Safety Vest, 1 Mask, 3 NO-Masks, 1 Person, 1 Safety Cone, 6 Machinerys, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/airport_inside_0460_jpg.rf.08bdc9d5bdd94eda87888c1082b3871f.jpg: 640x640 2 Hardhats, 1 NO-Safety Vest, 2 Masks, 2 NO-Masks, 3 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/airport_inside_0460_jpg.rf.aae905a80f304e8b4a3e3c738887490b.jpg: 640x640 6 Hardhats, 1 Safety Vest, 2 NO-Safety Vests, 3 Masks, 7 NO-Masks, 2 Safety Cones, 1 Machinery, 1 Vehicle, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/airport_inside_0550_jpg.rf.f2c346802de743043297e70687160686.jpg: 640x640 20 Persons, 1 Machinery, 1 Vehicle, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox4_mp4-111_jpg.rf.007d84ad1f436206297bbc55b174fff9.jpg: 640x640 11 Hardhats, 1 Safety Vest, 10 NO-Safety Vests, 2 Masks, 15 NO-Masks, 11 Persons, 13 Safety Cones, 2 Vehicles, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox4_mp4-111_jpg.rf.2292cbeef0a5da66dd9fe1040822d3e9.jpg: 640x640 8 Hardhats, 7 NO-Safety Vests, 1 Mask, 16 NO-Masks, 10 Persons, 10 Safety Cones, 2 Vehicles, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox4_mp4-112_jpg.rf.dfb0c2b0da41e5c1cc6287d06ee92aea.jpg: 640x640 2 Safety Vests, 2 NO-Safety Vests, 3 Masks, 2 NO-Masks, 1 Machinery, 2 Vehicles, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox4_mp4-72_jpg.rf.5e9c1836f027bf40eb8898e68f2efdeb.jpg: 640x640 8 Persons, 1 Vehicle, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox5_mp4-34_jpg.rf.e0c7d0632b6b6ec9aae7b89a2b096bea.jpg: 640x640 1 Person, 4 Machinerys, 1 Vehicle, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox6_mp4-157_jpg.rf.0bb6fec008de80af30afd18d1a6c676f.jpg: 640x640 1 Safety Vest, 2 NO-Safety Vests, 2 Masks, 3 NO-Masks, 5 Persons, 5 Machinerys, 9 Vehicles, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox6_mp4-20_jpg.rf.2ea83677536cb5929e57581ab983827b.jpg: 640x640 2 Hardhats, 1 Safety Vest, 1 NO-Safety Vest, 1 Mask, 5 NO-Masks, 3 Persons, 3 Safety Cones, 1 Machinery, 2 Vehicles, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/autox6_mp4-20_jpg.rf.ba6134721c0c752e7142a6299d2f04e9.jpg: 640x640 4 Safety Vests, 2 NO-Safety Vests, 3 Masks, 3 NO-Masks, 3 Persons, 2 Machinerys, 1 Vehicle, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1-_mp4-115_jpg.rf.2aa43302e55d176724bc0d99dcea9663.jpg: 640x640 1 Hardhat, 1 Safety Vest, 1 Mask, 2 NO-Masks, 4 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1-_mp4-115_jpg.rf.3180062637f2f2c6dac5a1a773a3d006.jpg: 640x640 1 Hardhat, 1 NO-Mask, 6 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1-_mp4-60_jpg.rf.30b09a8c2865e4922520e7d022dd9c61.jpg: 640x640 2 Hardhats, 1 Safety Vest, 1 NO-Safety Vest, 1 Mask, 3 NO-Masks, 1 Safety Cone, 1 Machinery, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1-_mp4-60_jpg.rf.645d185e1b6e0050a5c70dbd2136824c.jpg: 640x640 4 Hardhats, 1 Safety Vest, 4 NO-Safety Vests, 3 Masks, 6 NO-Masks, 3 Safety Cones, 2 Machinerys, 3 Vehicles, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1-_mp4-60_jpg.rf.73ba97ab2f23c2ef4776160a27424f5a.jpg: 640x640 1 NO-Mask, 2 Persons, 3 Machinerys, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1-_mp4-64_jpg.rf.92efd1b50f4e66f245f5705e2d6b7342.jpg: 640x640 5 Hardhats, 6 NO-Safety Vests, 4 Masks, 5 NO-Masks, 2 Machinerys, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1015-_jpg.rf.9e94d76133793a7dfe1aeb00e6ecd373.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 1 NO-Mask, 2 Machinerys, 1 Vehicle, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1023-_jpg.rf.7b73352606fb1d79619d34031c07a232.jpg: 640x640 2 Machinerys, 1 Vehicle, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1027-_jpg.rf.e78f55761814a8726ea51993407957af.jpg: 640x640 3 Machinerys, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1029-_jpg.rf.4b275026c8888b66ce2694d2dda856c3.jpg: 640x640 1 Hardhat, 1 NO-Hardhat, 1 Safety Vest, 2 NO-Safety Vests, 3 Masks, 3 NO-Masks, 2 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1029-_jpg.rf.99a91e79d6e2bf58dc80922f7d7c3adf.jpg: 640x640 10 Hardhats, 2 NO-Hardhats, 10 NO-Safety Vests, 1 Mask, 15 NO-Masks, 13 Safety Cones, 1 Machinery, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1029-_jpg.rf.e40ed9707d9ea79a66586b7eafe0ae52.jpg: 640x640 2 NO-Hardhats, 2 Safety Vests, 2 Masks, 2 NO-Masks, 2 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1029-_jpg.rf.f34331d792a26cbe94ef77e3251989ac.jpg: 640x640 1 NO-Hardhat, 1 Mask, 2 NO-Masks, 2 Machinerys, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1037-_jpg.rf.c44151f7f28c4da9757409953b1bff55.jpg: 640x640 2 Machinerys, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1062-_jpg.rf.30c06a00f2aef933ecf9aaa4b95f1320.jpg: 640x640 3 Hardhats, 3 Safety Vests, 2 NO-Safety Vests, 4 Masks, 6 NO-Masks, 1 Machinery, 1 Vehicle, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1099-_jpg.rf.df1d160085e954901f2efa84fd4a2e91.jpg: 640x640 1 NO-Hardhat, 1 Mask, 2 NO-Masks, 3 Machinerys, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1099-_jpg.rf.feeacd8e655f29f874d6bf1ae57cf022.jpg: 640x640 3 Hardhats, 1 NO-Hardhat, 2 NO-Safety Vests, 3 Masks, 4 NO-Masks, 1 Machinery, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1115-_jpg.rf.65aea4ef94ae0c57a90b44eb2056a940.jpg: 640x640 6 Hardhats, 2 Safety Vests, 5 NO-Safety Vests, 4 Masks, 5 NO-Masks, 1 Machinery, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1116-_jpg.rf.293365d3885eed0bcae63201c5ca15f6.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 2 NO-Masks, 3 Safety Cones, 3 Machinerys, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1116-_jpg.rf.89204e926b55ec2da9541d47c0b88309.jpg: 640x640 1 NO-Hardhat, 3 Masks, 2 NO-Masks, 2 Machinerys, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1116-_jpg.rf.d86e88d4a8ced388b86abff05c5aeefe.jpg: 640x640 1 Safety Vest, 3 NO-Safety Vests, 2 NO-Masks, 3 Machinerys, 1 Vehicle, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1116-_jpg.rf.da7f8f05689a5daf50a70fd109bb4a8f.jpg: 640x640 2 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-112-_jpg.rf.699d3c5a3155bb76ee6e10e842cc24de.jpg: 640x640 2 Hardhats, 1 NO-Safety Vest, 2 Masks, 3 NO-Masks, 1 Machinery, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-112-_jpg.rf.aff73a376ef301a11e45c58fb084e7a5.jpg: 640x640 1 NO-Mask, 1 Safety Cone, 4 Machinerys, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-1159-_jpg.rf.9f3172102a34edb157b556a73931c831.jpg: 640x640 1 Machinery, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-196-_jpg.rf.f593da25134315b48b325fb42436a01a.jpg: 640x640 1 Machinery, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-113_jpg.rf.657cf7274654eddca1d6c542cdee3dd0.jpg: 640x640 1 NO-Hardhat, 2 Safety Vests, 5 NO-Masks, 8 Persons, 2 Machinerys, 1 Vehicle, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-113_jpg.rf.b9c7bbcaf17702d65b9cccb60a39bb47.jpg: 640x640 3 Hardhats, 2 NO-Safety Vests, 2 Masks, 3 NO-Masks, 11 Persons, 1 Machinery, 1 Vehicle, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-12_jpg.rf.08cddb92471bc97a4bb37b6ce28b5655.jpg: 640x640 1 NO-Mask, 3 Machinerys, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-13_jpg.rf.cef0975976346515d438e0c2ce6c59db.jpg: 640x640 3 Machinerys, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-15_jpg.rf.94d743aaa79935634d2cc4ea6a5bfe2c.jpg: 640x640 2 Hardhats, 1 NO-Hardhat, 3 Safety Vests, 3 NO-Safety Vests, 3 Masks, 7 NO-Masks, 1 Safety Cone, 2 Machinerys, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-15_jpg.rf.a5fa6e719e0427f773a54c8d4cc19a1d.jpg: 640x640 2 NO-Hardhats, 1 Mask, 2 NO-Masks, 1 Safety Cone, 3 Machinerys, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-178_jpg.rf.0b86b7829e2da46f66cbf5dddb677a82.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 1 NO-Mask, 4 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-178_jpg.rf.7cea31ac9f8ab023bd65a904607a3d06.jpg: 640x640 1 Hardhat, 2 NO-Hardhats, 2 Safety Vests, 1 NO-Safety Vest, 2 Masks, 3 NO-Masks, 1 Safety Cone, 2 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-210_jpg.rf.2499564f33bc763f58c65a576f4afdd0.jpg: 640x640 2 Hardhats, 2 NO-Safety Vests, 1 Mask, 2 NO-Masks, 1 Safety Cone, 4 Machinerys, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-213_jpg.rf.3dc254f0ee3f229e0766837fcb916d24.jpg: 640x640 1 Mask, 5 NO-Masks, 5 Machinerys, 7 Vehicles, 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-213_jpg.rf.796b34b4516cfb4f1aefddbb912f01b5.jpg: 640x640 2 NO-Hardhats, 1 Safety Vest, 2 Masks, 2 NO-Masks, 2 Machinerys, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-219_jpg.rf.0ad7ddf87079cf198c8d4c90fb679f49.jpg: 640x640 1 NO-Hardhat, 1 Mask, 1 NO-Mask, 3 Persons, 1 Machinery, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-219_jpg.rf.d00dcbb1681782b09b105dd0c54d5852.jpg: 640x640 2 Hardhats, 3 NO-Hardhats, 1 Safety Vest, 1 Mask, 3 NO-Masks, 2 Safety Cones, 2 Machinerys, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-2-_mp4-219_jpg.rf.dae32347bb4fed1d2078263a64f58a70.jpg: 640x640 2 NO-Hardhats, 1 Safety Vest, 2 NO-Safety Vests, 3 Masks, 3 NO-Masks, 1 Safety Cone, 1 Machinery, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-207-_jpg.rf.67da281e0dc359a3d8e0ff40b561dfac.jpg: 640x640 1 NO-Hardhat, 1 Mask, 1 NO-Mask, 3 Machinerys, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-212-_jpg.rf.276f0a7fdf6fca4c0c75a1d69c095c28.jpg: 640x640 1 NO-Safety Vest, 2 Masks, 3 NO-Masks, 3 Machinerys, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-212-_jpg.rf.dfc3cd38ed63f7b7f642f8b1cbb1b68e.jpg: 640x640 4 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-253-_jpg.rf.0590780a5e0f86c9f306c71d7c3a3c6b.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 NO-Safety Vest, 1 Mask, 2 NO-Masks, 1 Machinery, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-260-_jpg.rf.b8584809048dd6843855f0f8c5b0a7a9.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 2 NO-Masks, 1 Safety Cone, 3 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-260-_jpg.rf.bed6cb4622027ec2bf56e6e5f0e8b2cc.jpg: 640x640 1 Safety Vest, 1 Mask, 1 NO-Mask, 6 Machinerys, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-267-_jpg.rf.222246f7ce5e3109de00144c4f603292.jpg: 640x640 2 NO-Hardhats, 2 Masks, 2 NO-Masks, 3 Machinerys, 6 Vehicles, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-267-_jpg.rf.36fd4d82d55aa7d307deccc95bb1b68e.jpg: 640x640 2 Hardhats, 2 Safety Vests, 1 NO-Safety Vest, 3 Masks, 5 NO-Masks, 1 Safety Cone, 1 Machinery, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-267-_jpg.rf.5c65fe4e77d4493d6788f644468d3939.jpg: 640x640 1 Hardhat, 4 NO-Masks, 1 Safety Cone, 10 Machinerys, 8 Vehicles, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-274-_jpg.rf.21181010ffb2b9ea429080ccd258e3ae.jpg: 640x640 2 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-275-_jpg.rf.e1c57987f9dc262aad1d7c67b694fd87.jpg: 640x640 1 NO-Mask, 1 Machinery, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-277-_jpg.rf.bf73a4edc7a1f7d412bc3267cbafcda7.jpg: 640x640 1 Machinery, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-122_jpg.rf.0cd1654e69130f2f2b2b5adb08c879f0.jpg: 640x640 2 Hardhats, 5 NO-Masks, 1 Person, 1 Safety Cone, 5 Machinerys, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-122_jpg.rf.7bb280627f23963d8fc187e624716358.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 1 NO-Mask, 5 Machinerys, 3 Vehicles, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-148_jpg.rf.20ec335e8625ddb4da3d7d656718c1bd.jpg: 640x640 1 Hardhat, 1 Mask, 4 NO-Masks, 2 Safety Cones, 4 Machinerys, 7.2ms
# Speed: 1.6ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-162_jpg.rf.52db765af29c85fdf701e0d4a7624fb4.jpg: 640x640 2 NO-Masks, 2 Safety Cones, 3 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-162_jpg.rf.9029ca82bb02bc31a4768f0f3e3655e4.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 2 Masks, 1 NO-Mask, 4 Machinerys, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-162_jpg.rf.d5b9deac1a1c1205d223e3d604afdd09.jpg: 640x640 1 Hardhat, 4 Safety Vests, 1 NO-Safety Vest, 7 Masks, 6 NO-Masks, 4 Machinerys, 1 Vehicle, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-162_jpg.rf.fcc17856f133926e2b49c657efcd48be.jpg: 640x640 3 NO-Masks, 7 Persons, 1 Safety Cone, 1 Machinery, 2 Vehicles, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-166_jpg.rf.3785bac9c8d14230444b9d7b9e669987.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 1 NO-Mask, 9 Persons, 2 Machinerys, 2 Vehicles, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-211_jpg.rf.7a50e0bbc5b5dcf920cbd67eeaa0c576.jpg: 640x640 1 Safety Vest, 1 Mask, 3 NO-Masks, 5 Persons, 8 Machinerys, 3 Vehicles, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-21_jpg.rf.4fc9ff5afc8387b5c673a424781c527c.jpg: 640x640 1 Mask, 1 NO-Mask, 4 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-3-_mp4-67_jpg.rf.2ac209d6daf4ac7a4247a4ee28385fe8.jpg: 640x640 1 Hardhat, 1 Safety Vest, 2 NO-Safety Vests, 4 NO-Masks, 2 Safety Cones, 4 Machinerys, 2 Vehicles, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-305-_jpg.rf.d6bf62f198a43cec387208b956a3c8f7.jpg: 640x640 3 Hardhats, 3 Masks, 7 NO-Masks, 2 Safety Cones, 6 Machinerys, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-331-_jpg.rf.ea29c106612a81b5265ea538ee457638.jpg: 640x640 2 Hardhats, 2 NO-Masks, 5 Machinerys, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-347-_jpg.rf.019a625d11ee3deb1aae360a2755d707.jpg: 640x640 14 Hardhats, 1 Safety Vest, 13 NO-Safety Vests, 17 NO-Masks, 14 Safety Cones, 1 Machinery, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-347-_jpg.rf.da66417ec4dc8d612f5613fa67c262c7.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 2 NO-Masks, 1 Safety Cone, 1 Machinery, 3 Vehicles, 7.6ms
# Speed: 1.7ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-347-_jpg.rf.f5e15e0e36d3cc7fcfbf49d68c21f121.jpg: 640x640 1 NO-Safety Vest, 2 Masks, 2 NO-Masks, 16 Persons, 1 Machinery, 1 Vehicle, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-369-_jpg.rf.23dd790f943919d62800543641ea8474.jpg: 640x640 2 Hardhats, 1 NO-Hardhat, 1 Safety Vest, 2 NO-Safety Vests, 1 Mask, 3 NO-Masks, 1 Safety Cone, 3 Machinerys, 7.2ms
# Speed: 1.6ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-369-_jpg.rf.27b76b8bb58e9f12d60cb654abdbf508.jpg: 640x640 1 Mask, 2 NO-Masks, 1 Safety Cone, 5 Machinerys, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-369-_jpg.rf.30fa5e9b5231010dabadf061d2db52d3.jpg: 640x640 2 NO-Hardhats, 1 Safety Vest, 2 Masks, 5 NO-Masks, 3 Machinerys, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-385-_jpg.rf.9f93c4ac5c55c8d091e71d7820d964c2.jpg: 640x640 1 NO-Mask, 3 Machinerys, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-127_jpg.rf.369dffc6c0812c73e687686e68e9bde3.jpg: 640x640 1 NO-Hardhat, 1 Mask, 3 NO-Masks, 1 Safety Cone, 4 Machinerys, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-127_jpg.rf.c8b5b8cd660a766336ecfcf953fe4305.jpg: 640x640 1 Safety Vest, 1 NO-Safety Vest, 1 Mask, 1 NO-Mask, 3 Machinerys, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-165_jpg.rf.245a89fb6862ed44d8698e334777bc6d.jpg: 640x640 1 Mask, 1 NO-Mask, 4 Machinerys, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-165_jpg.rf.5354cc400c056d38d93601f5e246639a.jpg: 640x640 3 NO-Hardhats, 1 Safety Vest, 5 NO-Safety Vests, 4 Masks, 6 NO-Masks, 4 Safety Cones, 2 Machinerys, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-182_jpg.rf.492a9e7be9451e34149bcbcb89c11810.jpg: 640x640 1 Safety Vest, 1 NO-Safety Vest, 3 NO-Masks, 1 Safety Cone, 5 Machinerys, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-182_jpg.rf.627a7713bb1819c97760a93546151040.jpg: 640x640 1 NO-Hardhat, 1 NO-Safety Vest, 2 Masks, 6 NO-Masks, 2 Safety Cones, 3 Machinerys, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-182_jpg.rf.de6b154c40fe604072fbd94399a9328a.jpg: 640x640 2 Hardhats, 1 Safety Vest, 2 NO-Safety Vests, 3 Masks, 3 NO-Masks, 2 Machinerys, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-182_jpg.rf.f72c3426b5e987bc41302d8309dcc192.jpg: 640x640 7 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-185_jpg.rf.2f9a20acb20029a8d99caf5f3b76e0b3.jpg: 640x640 2 NO-Masks, 1 Safety Cone, 6 Machinerys, 2 Vehicles, 7.2ms
# Speed: 1.6ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-188_jpg.rf.222a8ed73f017be9b2c3fb6c9e250bca.jpg: 640x640 2 Safety Vests, 2 NO-Safety Vests, 5 Masks, 7 NO-Masks, 2 Machinerys, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-188_jpg.rf.74d1b2d1747d25f44bf4d2c8f1fee247.jpg: 640x640 1 Safety Vest, 1 NO-Safety Vest, 2 Masks, 2 NO-Masks, 5 Machinerys, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-188_jpg.rf.b432a7682ba15224171e52a9c7d30a71.jpg: 640x640 2 Hardhats, 1 NO-Safety Vest, 2 NO-Masks, 12 Persons, 1 Safety Cone, 1 Machinery, 1 Vehicle, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-189_jpg.rf.f2e4339a999eb718ff43ad57e06b4da6.jpg: 640x640 1 Mask, 1 NO-Mask, 20 Persons, 1 Machinery, 2 Vehicles, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-19_jpg.rf.ae9b311efa6de4566e5c8ec20c3718fb.jpg: 640x640 1 NO-Mask, 1 Person, 2 Machinerys, 4 Vehicles, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-19_jpg.rf.b39073990b499b99dfe415a49fdb90bb.jpg: 640x640 1 NO-Mask, 4 Machinerys, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-38_jpg.rf.2e5287c7925dbf5a8ef8422c0e6fee27.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 3 Masks, 2 NO-Masks, 8 Persons, 4 Machinerys, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-41_jpg.rf.52ca8fcab8ce72c4dee7fefc91681934.jpg: 640x640 1 Hardhat, 1 NO-Hardhat, 1 Safety Vest, 2 NO-Safety Vests, 2 Masks, 3 NO-Masks, 1 Safety Cone, 2 Machinerys, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-41_jpg.rf.c5e4bcc5976beec3e62122474353665b.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 1 Mask, 1 NO-Mask, 1 Machinery, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-89_jpg.rf.bfb1483dd3989a71df592291d66d94fe.jpg: 640x640 5 NO-Hardhats, 1 Safety Vest, 1 NO-Mask, 4 Machinerys, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-94_jpg.rf.af104684c19a232f02c90552eaa84fbc.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 2 Masks, 2 NO-Masks, 3 Machinerys, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-94_jpg.rf.ed816f287bc4996348f474833197cdc0.jpg: 640x640 1 Safety Vest, 2 Masks, 2 NO-Masks, 3 Machinerys, 1 Vehicle, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-4-_mp4-94_jpg.rf.faa54990813350bf15eebdb3d1ace03d.jpg: 640x640 18 Hardhats, 18 NO-Safety Vests, 19 NO-Masks, 27 Safety Cones, 3 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-434-_jpg.rf.08f3862f335fb52c0e87c4664d373751.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 NO-Safety Vest, 2 Masks, 2 NO-Masks, 2 Machinerys, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-136_jpg.rf.3f565846fbd70422e73d09aab8c2c2b4.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 3 NO-Masks, 6 Machinerys, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-136_jpg.rf.4de970ffc60aa2cda3fb97f03350384a.jpg: 640x640 2 Hardhats, 1 NO-Hardhat, 4 Safety Vests, 6 NO-Safety Vests, 3 Masks, 6 NO-Masks, 3 Safety Cones, 2 Machinerys, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-136_jpg.rf.5781617c5a56e26adb37b2889ca6a0b8.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 1 NO-Mask, 28 Persons, 1 Machinery, 1 Vehicle, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-136_jpg.rf.61f13f9398c539e73446daa76339f1dc.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 2 NO-Masks, 3 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-136_jpg.rf.aeb3616a8195ab797c209691b9440b21.jpg: 640x640 2 Machinerys, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-29_jpg.rf.3aa8761e72a2a70eaae36cc6215f9618.jpg: 640x640 13 Persons, 9 Machinerys, 6 Vehicles, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-29_jpg.rf.3ab6fb82c7b98c1cdb491e40508707a8.jpg: 640x640 1 NO-Hardhat, 2 Safety Vests, 1 NO-Safety Vest, 6 Masks, 5 NO-Masks, 2 Machinerys, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-29_jpg.rf.b3d72d5b8af0726c69bd9a4387dcc631.jpg: 640x640 1 Mask, 2 NO-Masks, 3 Machinerys, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-30_jpg.rf.527821dcd495003327e1d90baeb2f8d3.jpg: 640x640 1 Hardhat, 1 Safety Vest, 1 NO-Safety Vest, 2 NO-Masks, 1 Person, 2 Safety Cones, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-39_jpg.rf.e828d532dce99528cc3afc47a75b6c29.jpg: 640x640 1 Mask, 3 NO-Masks, 3 Safety Cones, 3 Machinerys, 3 Vehicles, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-48_jpg.rf.4fdbba397c6dbde429373640d634e935.jpg: 640x640 1 Hardhat, 2 NO-Masks, 2 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-48_jpg.rf.82ca9f1ab7f0394a237c4938bdd913f9.jpg: 640x640 3 NO-Masks, 4 Machinerys, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-48_jpg.rf.869646c7e34f2451c66b6d9487b68281.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 1 Mask, 3 NO-Masks, 5 Machinerys, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-69_jpg.rf.db2363bd2d668608b713c20e248158b5.jpg: 640x640 2 NO-Masks, 3 Machinerys, 7.9ms
# Speed: 1.8ms preprocess, 7.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-75_jpg.rf.7d2e2174dc9edfdc8a1bab63ca89c39b.jpg: 640x640 1 Safety Vest, 1 NO-Safety Vest, 1 Mask, 2 NO-Masks, 3 Machinerys, 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-75_jpg.rf.fc0027e06829c22dbe4e71c973a99069.jpg: 640x640 2 Hardhats, 1 Safety Vest, 3 NO-Safety Vests, 1 Mask, 2 NO-Masks, 1 Safety Cone, 5 Machinerys, 7.9ms
# Speed: 1.8ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-96_jpg.rf.b34b00ccea66baa05cf4aa1db72c338b.jpg: 640x640 1 Hardhat, 4 NO-Masks, 2 Safety Cones, 4 Machinerys, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-98_jpg.rf.02e8260150fd9b4d149ebdf1b77ae87b.jpg: 640x640 4 Safety Vests, 3 NO-Safety Vests, 7 Masks, 8 NO-Masks, 1 Machinery, 2 Vehicles, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-98_jpg.rf.d740dd74b71d71e5b4377878190090ad.jpg: 640x640 2 Safety Vests, 1 NO-Safety Vest, 1 Mask, 2 NO-Masks, 1 Person, 1 Machinery, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-5-_mp4-98_jpg.rf.f30eaa2acd13890a1ec29645af90bab9.jpg: 640x640 1 Safety Vest, 2 NO-Masks, 3 Machinerys, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-507-_jpg.rf.ff1f7ff6c3ee0a5495251801e04151c8.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 2 NO-Masks, 3 Machinerys, 6.5ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-523-_jpg.rf.39fe60c11ac70b73c2cc469124bb1762.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 5 NO-Masks, 6 Persons, 3 Machinerys, 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-528-_jpg.rf.3578451e1fd09479e3ddb770aafd00e5.jpg: 640x640 1 NO-Hardhat, 2 Safety Vests, 2 NO-Safety Vests, 3 Masks, 3 NO-Masks, 3 Machinerys, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-528-_jpg.rf.8aca598ebfb9d8074d1e7f4763674d73.jpg: 640x640 2 Hardhats, 3 Safety Vests, 3 NO-Safety Vests, 5 Masks, 7 NO-Masks, 2 Machinerys, 1 Vehicle, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-528-_jpg.rf.cf2c53e133b7c53f3374d4bb2e6c6b89.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 1 NO-Mask, 5 Machinerys, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-528-_jpg.rf.fda69fe0d66335b4bfa3cc37671f3a68.jpg: 640x640 2 NO-Hardhats, 1 Safety Vest, 1 Mask, 2 NO-Masks, 1 Machinery, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-543-_jpg.rf.36a5fb92366cc6bc65b8b2c28f27bdab.jpg: 640x640 2 NO-Masks, 3 Machinerys, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-543-_jpg.rf.4ac68b4606a6eecb76a48df1ae8ae96a.jpg: 640x640 1 Mask, 2 NO-Masks, 2 Persons, 1 Machinery, 2 Vehicles, 6.9ms
# Speed: 1.4ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-543-_jpg.rf.649ab011cb782b350dff83fdb605e65a.jpg: 640x640 3 NO-Hardhats, 5 Safety Vests, 1 Mask, 7 NO-Masks, 2 Machinerys, 7.2ms
# Speed: 1.5ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-547-_jpg.rf.017820bddb0437be352dba7b5836a545.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 Mask, 2 NO-Masks, 6 Machinerys, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-547-_jpg.rf.5a75e2e90f7e6e23620b4311cb7bf65e.jpg: 640x640 1 NO-Mask, 14 Persons, 2 Machinerys, 1 Vehicle, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-560-_jpg.rf.2ce0dca7431fa99fdc542ddb0b8f9651.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 1 Mask, 2 NO-Masks, 3 Machinerys, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-560-_jpg.rf.6c3e097caafb9f23de0e94b6bb9c9684.jpg: 640x640 2 Safety Vests, 2 NO-Safety Vests, 1 Mask, 2 NO-Masks, 5 Machinerys, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-560-_jpg.rf.77991e7505048da45e44fa988ce9ee0a.jpg: 640x640 2 Safety Vests, 2 NO-Safety Vests, 1 Mask, 7 NO-Masks, 3 Machinerys, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-618-_jpg.rf.45e203c3c474c1f50e6c4309badfc748.jpg: 640x640 2 Hardhats, 2 NO-Safety Vests, 5 NO-Masks, 2 Safety Cones, 3 Machinerys, 1 Vehicle, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-619-_jpg.rf.195c36f2b32843181bf4dfb5ffad2707.jpg: 640x640 1 NO-Safety Vest, 1 NO-Mask, 2 Persons, 1 Safety Cone, 2 Vehicles, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/construction-619-_jpg.rf.8181765b21d618233610f2c91a6057a4.jpg: 640x640 2 Hardhats, 1 Safety Vest, 3 NO-Safety Vests, 3 Masks, 5 NO-Masks, 3 Machinerys, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# ...
# Speed: 2.1ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-459_jpg.rf.7197e47830c027d29c81a960ce19d7c7.jpg: 640x640 1 Person, 4 Machinerys, 7.2ms
# Speed: 1.5ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-462_jpg.rf.df73aa5089a04b8fbf3adf9d614a6740.jpg: 640x640 2 Hardhats, 2 NO-Masks, 2 Safety Cones, 1 Vehicle, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-464_jpg.rf.355495bd54c66f71e909fa906b77e184.jpg: 640x640 2 Hardhats, 1 NO-Safety Vest, 3 NO-Masks, 1 Safety Cone, 2 Machinerys, 2 Vehicles, 7.9ms
# Speed: 1.8ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-464_jpg.rf.8784a32dc660e889975cf6d6065c469a.jpg: 640x640 1 NO-Mask, 2 Persons, 1 Safety Cone, 2 Machinerys, 2 Vehicles, 7.5ms
# Speed: 2.2ms preprocess, 7.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-471_jpg.rf.4296b7bd9a5a07753077beddbcd651bf.jpg: 640x640 1 Safety Cone, 7.2ms
# Speed: 1.4ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-474_jpg.rf.a69f31210940425bb2099ce9f6683645.jpg: 640x640 1 NO-Mask, 1 Machinery, 1 Vehicle, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-497_jpg.rf.b8b5f459b6bf69cc2383c6f8f7de916d.jpg: 640x640 1 NO-Mask, 3 Machinerys, 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-497_jpg.rf.de718ed675c4ac0cb19ccccac738aeb2.jpg: 640x640 1 Hardhat, 2 NO-Masks, 1 Machinery, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-49_jpg.rf.5a44fe43dd47987a1b67b83e743ea9ce.jpg: 640x640 1 Safety Vest, 1 NO-Safety Vest, 1 NO-Mask, 2 Machinerys, 1 Vehicle, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-506_jpg.rf.f6eb407abb8cd008124e1178d332a64b.jpg: 640x640 1 Hardhat, 3 Safety Vests, 4 Masks, 5 NO-Masks, 1 Machinery, 7.4ms
# Speed: 1.5ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-507_jpg.rf.9dd5d0a2881420c1b72fa4749c1d8830.jpg: 640x640 1 Safety Vest, 2 NO-Masks, 1 Safety Cone, 2 Machinerys, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-507_jpg.rf.a859758779df04ea778068a73b402d3c.jpg: 640x640 1 Hardhat, 2 NO-Hardhats, 2 Safety Vests, 4 NO-Masks, 1 Safety Cone, 1 Machinery, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-550_jpg.rf.0a199dbd9cdb73adb689576c257cd853.jpg: 640x640 1 NO-Hardhat, 1 Mask, 1 NO-Mask, 4 Machinerys, 1 Vehicle, 8.6ms
# Speed: 1.6ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-554_jpg.rf.12abc545630972a6e272892494a59dcc.jpg: 640x640 1 Hardhat, 1 NO-Hardhat, 1 NO-Safety Vest, 1 Mask, 4 NO-Masks, 1 Person, 1 Safety Cone, 2 Machinerys, 2 Vehicles, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-554_jpg.rf.7c697c7deea9995a0145e96cb7a23797.jpg: 640x640 1 Mask, 1 NO-Mask, 5 Machinerys, 9.2ms
# Speed: 1.6ms preprocess, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-560_jpg.rf.8f99653f70bc2287a75c70758e5a43e0.jpg: 640x640 4 Hardhats, 1 NO-Safety Vest, 4 Masks, 7 NO-Masks, 1 Safety Cone, 7.2ms
# Speed: 1.6ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-564_jpg.rf.4d53a205cd034c39472c8ceebf3af69d.jpg: 640x640 1 NO-Hardhat, 1 NO-Mask, 1 Safety Cone, 1 Machinery, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-571_jpg.rf.445722ace33f1fd733756c215912b3a8.jpg: 640x640 1 NO-Mask, 2 Machinerys, 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-571_jpg.rf.d380c7fde4b25c50887691ab5d5dcfac.jpg: 640x640 2 Hardhats, 2 NO-Hardhats, 3 NO-Masks, 2 Safety Cones, 1 Machinery, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-574_jpg.rf.3e198affe680e93fff82325572cc6972.jpg: 640x640 2 NO-Masks, 2 Safety Cones, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-574_jpg.rf.ec53f3e134d613ec561e1f7fb9e56db2.jpg: 640x640 3 Hardhats, 1 NO-Safety Vest, 2 NO-Masks, 4 Safety Cones, 7.6ms
# Speed: 1.7ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-579_jpg.rf.db114ff0f07961521749739faca4fbcb.jpg: 640x640 1 Hardhat, 2 NO-Masks, 2 Safety Cones, 1 Machinery, 2 Vehicles, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-57_jpg.rf.87a1f2203f761f29bdf0543239ec739d.jpg: 640x640 2 Persons, 2 Machinerys, 2 Vehicles, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-615_jpg.rf.7f41bbb94234c00582504401d4a76a60.jpg: 640x640 4 NO-Masks, 1 Person, 1 Safety Cone, 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-641_jpg.rf.aa36d0a940f13bcbd69f98d5309960b4.jpg: 640x640 1 NO-Safety Vest, 1 Mask, 2 NO-Masks, 1 Safety Cone, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-641_jpg.rf.f8e9bcb9a5aba1a0fab955a47ea38760.jpg: 640x640 1 Hardhat, 1 Safety Vest, 1 NO-Safety Vest, 1 Mask, 5 NO-Masks, 1 Safety Cone, 1 Machinery, 8.9ms
# Speed: 1.6ms preprocess, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-645_jpg.rf.0cae206994074c96880eee9f8b4f6fa0.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 1 Mask, 1 NO-Mask, 1 Machinery, 8.9ms
# Speed: 1.5ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-645_jpg.rf.678dd020ed3048e268f7768a6df08cf8.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 NO-Mask, 1 Machinery, 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-661_jpg.rf.96b27bc1550d9c74255de3061c1d61cb.jpg: 640x640 1 Person, 2 Vehicles, 7.2ms
# Speed: 1.6ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-667_jpg.rf.8c29596b7486388ed0cdf3da93f73cd4.jpg: 640x640 1 NO-Hardhat, 1 Safety Vest, 1 NO-Mask, 2 Machinerys, 2 Vehicles, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-668_jpg.rf.179b654b1f4c6574010186dd4fbdd475.jpg: 640x640 1 Person, 1 Machinery, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-668_jpg.rf.4aa90caeca7a6635021aea2a4f3ccf13.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 2 NO-Masks, 1 Safety Cone, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-668_jpg.rf.ce3804ef6c8f28490efeb8d2b5d52090.jpg: 640x640 2 NO-Hardhats, 1 NO-Mask, 7.4ms
# Speed: 1.5ms preprocess, 7.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-693_jpg.rf.1fe523c5b5c19d9b16bfb8b8a20fb29f.jpg: 640x640 1 NO-Mask, 2 Machinerys, 7.0ms
# Speed: 1.5ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-695_jpg.rf.19a86e22fe4a33c49cba7546d5e6498d.jpg: 640x640 2 Hardhats, 1 NO-Safety Vest, 7 NO-Masks, 5 Safety Cones, 1 Machinery, 1 Vehicle, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-699_jpg.rf.ced94dd4765a8ff9fe60e7648179fb6d.jpg: 640x640 1 Hardhat, 2 NO-Masks, 2 Safety Cones, 1 Machinery, 2 Vehicles, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-726_jpg.rf.7ca57d637c5acb0d2772e0815a6d80e3.jpg: 640x640 1 NO-Mask, 2 Machinerys, 8.8ms
# Speed: 2.1ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-726_jpg.rf.9217e70297b89a7a06e94a1432196d79.jpg: 640x640 1 NO-Hardhat, 1 Mask, 2 NO-Masks, 2 Machinerys, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-730_jpg.rf.26bec93a311351ca9c06119164ef8de5.jpg: 640x640 2 NO-Masks, 1 Safety Cone, 2 Vehicles, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-730_jpg.rf.b55e41b07155a1b30073fb0e4da9e1b7.jpg: 640x640 2 NO-Hardhats, 2 Safety Vests, 1 NO-Mask, 1 Safety Cone, 9.0ms
# Speed: 2.2ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-731_jpg.rf.47b70ce0a8b8a93aca5916119175a04c.jpg: 640x640 1 Hardhat, 1 Mask, 3 NO-Masks, 1 Safety Cone, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-806_jpg.rf.c8952e265f0c4af327b56f43b365537a.jpg: 640x640 1 NO-Mask, 1 Safety Cone, 1 Machinery, 1 Vehicle, 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-809_jpg.rf.6fb92c2982d1c552da9c5ba10ff72d5e.jpg: 640x640 7 Persons, 1 Machinery, 7.2ms
# Speed: 1.5ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-812_jpg.rf.a5f34a08b407b48f43169f49917906a2.jpg: 640x640 1 NO-Hardhat, 2 Safety Vests, 2 NO-Masks, 1 Machinery, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-813_jpg.rf.63b422efff31ad667fbb228d39e0a2eb.jpg: 640x640 1 Hardhat, 1 NO-Hardhat, 1 NO-Safety Vest, 2 NO-Masks, 1 Safety Cone, 1 Vehicle, 8.2ms
# Speed: 1.6ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-813_jpg.rf.b9c7825c3711b9f313376a12b75553f3.jpg: 640x640 2 Hardhats, 1 Safety Vest, 3 NO-Masks, 2 Persons, 2 Safety Cones, 1 Vehicle, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-813_jpg.rf.f0b08055ea368a39e7846182b7af0102.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 3 NO-Masks, 2 Safety Cones, 7.2ms
# Speed: 1.4ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-815_jpg.rf.efcb04fd1022521a86e34b4fde943808.jpg: 640x640 1 NO-Hardhat, 2 NO-Masks, 1 Person, 3 Vehicles, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-837_jpg.rf.1c9fe1c871e46ff877c1f2b443576319.jpg: 640x640 2 NO-Masks, 1 Safety Cone, 1 Machinery, 1 Vehicle, 7.7ms
# Speed: 1.6ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-848_jpg.rf.420254c4553963c6c3d957e2cc961a34.jpg: 640x640 1 Hardhat, 1 Mask, 3 NO-Masks, 1 Safety Cone, 2 Machinerys, 2 Vehicles, 7.6ms
# Speed: 1.6ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-848_jpg.rf.bef04dc9e34440277e80f82cbdce6e8a.jpg: 640x640 1 Hardhat, 1 NO-Mask, 1 Safety Cone, 2 Machinerys, 1 Vehicle, 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/youtube-849_jpg.rf.dfaabf6f93250fdbe0809582859b6397.jpg: 640x640 1 Hardhat, 1 NO-Mask, 1 Machinery, 2 Vehicles, 7.5ms
# Speed: 1.5ms preprocess, 7.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Confidence Threshold Analysis:
# Confidence Threshold  Total Detections  Avg Confidence  Min Confidence
#                 0.10              5830        0.601578        0.100028
#                 0.25              4674        0.710519        0.251158
#                 0.50              3800        0.788739        0.500004
#                 0.75              2598        0.855748        0.750018
# ============================================================
# ✓ Confidence threshold analysis visualized and saved

# %% [markdown]
# ## Per-Class Performance
#
# Analyzing detection statistics for each PPE class to identify which objects the model detects most reliably and which are challenging.

# %%
# Calculate per-class detection metrics
class_detection_counts = defaultdict(int)
class_avg_confidence = defaultdict(list)

for pred in predictions:
    class_detection_counts[pred['class_name']] += 1
    class_avg_confidence[pred['class_name']].append(pred['confidence'])

# Compute comprehensive per-class statistics
class_stats = []
for class_name in sorted(class_detection_counts.keys()):
    count = class_detection_counts[class_name]
    confidences = class_avg_confidence[class_name]

    class_stats.append({
        'Class': class_name,
        'Detections': count,
        'Avg Confidence': np.mean(confidences),
        'Min Confidence': np.min(confidences),
        'Max Confidence': np.max(confidences),
        'Std Confidence': np.std(confidences)
    })

class_stats_df = pd.DataFrame(class_stats)
print("\nPer-Class Detection Statistics:")
print("=" * 60)
print(class_stats_df.to_string(index=False))
print("=" * 60)

# Visualize per-class metrics
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

colors = [class_colors[i] for i in range(10)]
colors_normalized = [(c[2]/255, c[1]/255, c[0]/255) for c in colors]

# Detection counts
axes[0].barh(class_stats_df['Class'], class_stats_df['Detections'],
            color=colors_normalized, edgecolor='black', alpha=0.8)
axes[0].set_xlabel('Number of Detections', fontsize=11)
axes[0].set_title('Detection Count by Class', fontsize=12, fontweight='bold')
axes[0].grid(alpha=0.3, axis='x')

# Average confidence
axes[1].barh(class_stats_df['Class'], class_stats_df['Avg Confidence'],
            color=colors_normalized, edgecolor='black', alpha=0.8)
axes[1].set_xlabel('Average Confidence Score', fontsize=11)
axes[1].set_xlim(0, 1)
axes[1].set_title('Average Detection Confidence by Class', fontsize=12, fontweight='bold')
axes[1].grid(alpha=0.3, axis='x')

plt.tight_layout()
plt.savefig('per_class_metrics.png', dpi=150, bbox_inches='tight')
plt.show()

print("✓ Per-class metrics visualized and saved as 'per_class_metrics.png'")
# Out:
# Per-Class Detection Statistics:
# ============================================================
#          Class  Detections  Avg Confidence  Min Confidence  Max Confidence  Std Confidence
#        Hardhat         414        0.704499        0.251580        0.923595        0.170359
#      Machinery         933        0.809061        0.252562        0.982970        0.173090
#           Mask         423        0.675520        0.259912        0.958120        0.178960
#     NO-Hardhat         151        0.769410        0.275250        0.906451        0.148026
#        NO-Mask        1139        0.724105        0.251158        0.983392        0.200063
# NO-Safety Vest         371        0.580241        0.254897        0.886432        0.183630
#         Person         366        0.597796        0.251512        0.940575        0.196859
#    Safety Cone         418        0.717120        0.251218        0.974453        0.171894
#    Safety Vest         234        0.655648        0.251247        0.904082        0.187172
#        Vehicle         225        0.713462        0.251994        0.976466        0.208824
# ============================================================
# ✓ Per-class metrics visualized and saved as 'per_class_metrics.png'

# %% [markdown]
# ## Section 8: Confidence Distribution Analysis
#
# Visualize the distribution of confidence scores to understand model certainty in its predictions.

# %%
# Analyze confidence score distribution
all_confidences = [p['confidence'] for p in predictions]

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogram
axes[0].hist(all_confidences, bins=50, color='teal', alpha=0.7, edgecolor='black')
axes[0].set_xlabel('Confidence Score', fontsize=11)
axes[0].set_ylabel('Frequency', fontsize=11)
axes[0].set_title('Distribution of Confidence Scores', fontsize=12, fontweight='bold')
axes[0].axvline(np.mean(all_confidences), color='red', linestyle='--',
                linewidth=2, label=f'Mean: {np.mean(all_confidences):.3f}')
axes[0].axvline(np.median(all_confidences), color='orange', linestyle='--',
                linewidth=2, label=f'Median: {np.median(all_confidences):.3f}')
axes[0].legend()
axes[0].grid(alpha=0.3)

# Box plot by class
class_confidence_data = []
class_labels = []
for class_name in sorted(class_detection_counts.keys()):
    class_confidence_data.append(class_avg_confidence[class_name])
    class_labels.append(class_name)

bp = axes[1].boxplot(class_confidence_data, labels=class_labels, vert=True, patch_artist=True)
for patch, color in zip(bp['boxes'], colors_normalized):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)
axes[1].set_xlabel('Class', fontsize=11)
axes[1].set_ylabel('Confidence Score', fontsize=11)
axes[1].set_title('Confidence Distribution by Class', fontsize=12, fontweight='bold')
axes[1].tick_params(axis='x', rotation=45)
axes[1].grid(alpha=0.3, axis='y')

plt.tight_layout()
plt.savefig('confidence_distribution.png', dpi=150, bbox_inches='tight')
plt.show()

print("✓ Confidence distribution visualized and saved")
# Out:
# ✓ Confidence distribution visualized and saved

# %% [markdown]
# ## Section 9: Failure Case Analysis
#
# Identify and visualize images where the model struggles (low confidence detections or missed objects). This helps us understand the model's limitations and potential areas for improvement.

# %%
# Identify challenging cases with low confidence
low_confidence_threshold = 0.5
low_confidence_images = pred_df[pred_df['confidence'] < low_confidence_threshold]['image'].unique()

print(f"Challenging Cases Analysis:")
print("=" * 60)
print(f"Images with low confidence detections (<{low_confidence_threshold}): {len(low_confidence_images)}")
print("=" * 60)

# Visualize challenging cases
if len(low_confidence_images) > 0:
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    fig.suptitle(f'Challenging Cases - Low Confidence Predictions (<{low_confidence_threshold})',
                 fontsize=14, fontweight='bold')

    for idx, img_name in enumerate(list(low_confidence_images)[:6]):
        row = idx // 3
        col = idx % 3

        img_path = test_dir / img_name
        results = model(str(img_path), conf=0.1, iou=0.45)  # Lower threshold to see all detections
        pred_img = draw_predictions(str(img_path), results)

        # Count low confidence detections
        low_conf_count = len(pred_df[(pred_df['image'] == img_name) &
                                      (pred_df['confidence'] < low_confidence_threshold)])

        axes[row, col].imshow(pred_img)
        axes[row, col].set_title(f'{img_name}\nLow Conf: {low_conf_count}', fontsize=9)
        axes[row, col].axis('off')

    # Hide empty subplots
    for idx in range(len(low_confidence_images), 6):
        row = idx // 3
        col = idx % 3
        axes[row, col].axis('off')

    plt.tight_layout()
    plt.savefig('low_confidence_cases.png', dpi=150, bbox_inches='tight')
    plt.show()

    print("✓ Failure case analysis visualized and saved as 'low_confidence_cases.png'")
else:
    print("No low confidence cases found!")
# Out:
# Challenging Cases Analysis:
# ============================================================
# Images with low confidence detections (<0.5): 308
# ============================================================
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/003184_jpg.rf.e7b83a5faa2513c5d2201944e2b2bd17.jpg: 640x640 3 Masks, 6 NO-Masks, 3 Machinerys, 1 Vehicle, 7.4ms
# Speed: 1.7ms preprocess, 7.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/005310_jpg.rf.3fadf8fa69fb354db06bed4e42142276.jpg: 640x640 3 Hardhats, 1 NO-Safety Vest, 3 Masks, 4 NO-Masks, 1 Safety Cone, 1 Machinery, 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/005310_jpg.rf.462b38e32ee1aed612c4ed119dc9a06e.jpg: 640x640 1 Hardhat, 5 NO-Masks, 13 Persons, 2 Safety Cones, 1 Machinery, 1 Vehicle, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/005310_jpg.rf.5b524ed76d3e591d22c323212f22943f.jpg: 640x640 7 Machinerys, 2 Vehicles, 7.2ms
# Speed: 1.6ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/006858_jpg.rf.c94da6aa210f1738a87f3525da7b5985.jpg: 640x640 1 NO-Hardhat, 2 Safety Vests, 1 NO-Safety Vest, 6 Masks, 9 NO-Masks, 1 Machinery, 1 Vehicle, 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/PPE_Project/dataset_resplit/images/test/129_jpg.rf.6ffe5c397bf302ae2bf05108d292a3f8.jpg: 640x640 2 Hardhats, 1 NO-Hardhat, 1 Safety Vest, 1 NO-Safety Vest, 4 Masks, 3 NO-Masks, 2 Persons, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# ✓ Failure case analysis visualized and saved as 'low_confidence_cases.png'

# %% [markdown]
# ## Section 10: Detection Distribution
#
# Visualize overall distribution of detections across classes to understand which objects are most frequently detected in the test set.

# %%
# Visualize detection distribution
fig, ax = plt.subplots(figsize=(10, 8))

class_names = list(ppe_classes.values())
detection_counts = [class_detection_counts.get(cls, 0) for cls in class_names]

colors_list = [class_colors[i] for i in range(10)]
colors_normalized = [(c[2]/255, c[1]/255, c[0]/255) for c in colors_list]

bars = ax.barh(class_names, detection_counts, color=colors_normalized,
               edgecolor='black', alpha=0.8)
ax.set_xlabel('Number of Detections', fontsize=11)
ax.set_title('Detection Distribution Across All Classes', fontsize=12, fontweight='bold')
ax.grid(alpha=0.3, axis='x')

# Add value labels on bars
for bar, count in zip(bars, detection_counts):
    width = bar.get_width()
    ax.text(width, bar.get_y() + bar.get_height()/2,
            f' {count}', ha='left', va='center', fontweight='bold')

plt.tight_layout()
plt.savefig('detection_distribution.png', dpi=150, bbox_inches='tight')
plt.show()

print("✓ Detection distribution visualized and saved as 'detection_distribution.png'")
# Out:
# ✓ Detection distribution visualized and saved as 'detection_distribution.png'

# %% [markdown]
# ## Section 11: Comprehensive Evaluation Report
#
# Generate final evaluation report with all metrics and statistics.

# %%
# Generate comprehensive evaluation summary
summary_report = f"""
================================================================================
YOLOV8 PPE DETECTION MODEL - COMPREHENSIVE EVALUATION REPORT
================================================================================

MODEL INFORMATION:
  Architecture: YOLOv8s (Small) - Maximum Accuracy Configuration
  Input Size: 640x640
  Total Parameters: {sum(p.numel() for p in model.model.parameters()):,}
  Model Path: {model_path}

DATASET STATISTICS:
  Train Images: {len(list(Path('/content/drive/MyDrive/PPE_Project/dataset_resplit/images/train').glob('*.jpg')))}
  Validation Images: {len(list(Path('/content/drive/MyDrive/PPE_Project/dataset_resplit/images/valid').glob('*.jpg')))}
  Test Images: {len(list(Path('/content/drive/MyDrive/PPE_Project/dataset_resplit/images/test').glob('*.jpg')))}
  Number of Classes: 10

OVERALL PERFORMANCE METRICS:
  mAP@50:       {val_results.box.map50:.4f}
  mAP@50-95:    {val_results.box.map:.4f}
  Precision:    {val_results.box.mp:.4f}
  Recall:       {val_results.box.mr:.4f}

TEST SET INFERENCE STATISTICS:
  Total Detections: {len(predictions)}
  Average Confidence: {np.mean(all_confidences):.4f}
  Median Confidence: {np.median(all_confidences):.4f}
  Std Dev Confidence: {np.std(all_confidences):.4f}

PER-CLASS STATISTICS:
{class_stats_df.to_string(index=False)}

CHALLENGING CASES:
  Images with low confidence (<{low_confidence_threshold}): {len(low_confidence_images)}

EVALUATION COMPLETE
================================================================================
"""

print(summary_report)

# Save report to file
with open('/content/evaluation_report.txt', 'w') as f:
    f.write(summary_report)

print("✓ Evaluation report saved to /content/evaluation_report.txt")

print("\n" + "="*70)
print("✓ MODEL EVALUATION COMPLETE")
print("✓ Ready to proceed to Notebook 04: Interactive Demo")
print("="*70)
# Out:
# ================================================================================
# YOLOV8 PPE DETECTION MODEL - COMPREHENSIVE EVALUATION REPORT
# ================================================================================
#
# MODEL INFORMATION:
#   Architecture: YOLOv8s (Small) - Maximum Accuracy Configuration
#   Input Size: 640x640
#   Total Parameters: 11,129,454
#   Model Path: /content/drive/MyDrive/PPE_Project/runs/detect/ppe_detection4/weights/best.pt
#
# DATASET STATISTICS:
#   Train Images: 1955
#   Validation Images: 0
#   Test Images: 423
#   Number of Classes: 10
#
# OVERALL PERFORMANCE METRICS:
#   mAP@50:       0.7710
#   mAP@50-95:    0.5006
#   Precision:    0.8894
#   Recall:       0.6887
#
# TEST SET INFERENCE STATISTICS:
#   Total Detections: 4674
#   Average Confidence: 0.7105
#   Median Confidence: 0.7746
#   Std Dev Confidence: 0.1970
#
# PER-CLASS STATISTICS:
#          Class  Detections  Avg Confidence  Min Confidence  Max Confidence  Std Confidence
#        Hardhat         414        0.704499        0.251580        0.923595        0.170359
#      Machinery         933        0.809061        0.252562        0.982970        0.173090
#           Mask         423        0.675520        0.259912        0.958120        0.178960
#     NO-Hardhat         151        0.769410        0.275250        0.906451        0.148026
#        NO-Mask        1139        0.724105        0.251158        0.983392        0.200063
# NO-Safety Vest         371        0.580241        0.254897        0.886432        0.183630
#         Person         366        0.597796        0.251512        0.940575        0.196859
#    Safety Cone         418        0.717120        0.251218        0.974453        0.171894
#    Safety Vest         234        0.655648        0.251247        0.904082        0.187172
#        Vehicle         225        0.713462        0.251994        0.976466        0.208824
#
# CHALLENGING CASES:
#   Images with low confidence (<0.5): 308
#
# EVALUATION COMPLETE
# ================================================================================
#
# ✓ Evaluation report saved to /content/evaluation_report.txt
#
# ======================================================================
# ✓ MODEL EVALUATION COMPLETE
# ✓ Ready to proceed to Notebook 04: Interactive Demo
# ======================================================================
